# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Огурлиев Анзор, я буду ревьюером твоего проекта. Сразу хочу предложить тебе общаться на "ты", если тебе это неудобно, скажи мне об этом. Нам предстоит пройти с тобой через тернистый и от того интересный путь анализа данных! Можешь не переживать, я всегда помогу тебе, если у тебя возникнут вопросы)
#
# По ходу твоей работы я буду оставлять свои комментарии, по выполненным тобой шагам. Попрошу тебя не удалять их, так мне будет проще отслеживать твой прогресс в случае повторной проверки.
#
# Очень важно вести диалог и обсуждать те пункты, которые у тебя могли не получиться, поэтому, ты можешь оставлять свои комментарии, и мы обязательно во всем разберемся! Самое главное - выделяй свои комментарии удобным для тебя способом (цвет, рамка), но так, чтобы они отчетлитво отличались от моих комментариев. Так мы ни в чем не запутаемся)
#
# Свои комментарии я буду выделять так: <font color='green'>зеленый</font>, <font color='gold'>желтый</font> и <font color='red'>красный</font> цвет, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Этот комментарий я буду оставлять, если твое решение оптимально для данного шага.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Это не означает, что ты совершил ошибку. Такими комментариями я буду отмечать места, где ты справился с задачей, но её можно решить ещё лучше. Также в таких комментариях я буду оставлять для тебя другие советы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Если решение, которое ты применил на определенном шаге, требует значительных изменений, то я буду оставлять такой комментарий. Тебе нужно будет подумать еще раз как правильным образом решить данный этап. Если ревью содержит такие комментарии, то я не смогу принять проект с первого раза.
# </div>
#
# P.S. В оглавлении комментария ты увидишь `V1` (`V1`, `V2`, `V3`) - это версия моего комментария, которая понадобится нам с тобой, чтобы не запутаться, если потребуется оставить тебе комментарии после первой проверки.

# %% [markdown]
# <div style="border:solid black 2px; padding: 40px">
#     Привет, Анзор! Меня зовут Даниил. Свои комментарии буду оставлять в черной рамке :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Привет, хорошо)

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости.
#
# Задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что начинаешь проект с описания.

# %% [markdown]
# ## ОБЩАЯ ИНФОРМАЦИЯ О ДАННЫХ

# %% [markdown]
# Импортируем библиотеки, необходимые для дальнейшей работы.

# %%
# импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# данный класс понадобился для выделения текста при выводе текста
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %% [markdown]
# Открываем файлы с данными и сохраняем их, как датафрейм.

# %%
try:
    data = pd.read_csv('/Users/daniil/Desktop/yandex-practicum-projects/03/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# Выведем первые 5 строчек для ознокомления с данными.

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Выведем краткое описание датафрейма.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Все столбцы являются ненулевыми. Колличество ненулевых значений отличается в различных столбцах. Названия столбцов 'cityCenters_nearest', 'parks_around3000', 'ponds_around3000' не соответствует принятому общепринятому стилю. Также мы видим, что типы значений в столбцах 'first_day_exposition', 'floors_total', 'is_apartment' являются ошибочными и их впоследствии нужно будет привести к корректному типу.

# %% [markdown]
# Для начала приведем все столбцы к общепринятому стилю и проверим, что в остальных столбцах отсутствуют лишние пробелы в названиях.

# %%
data = data.rename(
    columns={'cityCenters_nearest':'city_centers_nearest',
            'parks_around3000':'parks_around_3000',
            'ponds_around3000':'ponds_around_3000'}
)
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Составим наглядную таблицу, в которой мы будем видеть основные параметры, с которыми нам предстоит работать далее.

# %%
info_table = pd.DataFrame()

for column in data.columns:
    info_table[column] = [
        data[column].dtypes,
        data[column].isna().sum(),
        round(data[column].isna().mean() * 100),
        data[column].unique(),
        data[column].nunique()
    ]

info_table = info_table.T.rename(
    columns={
        0:'Тип данных',
        1:'Колл-во пропусков, шт.',
        2:'Колл-во пропусков, %',
        3:'Уникальные значение',
        4:'Колл-во уникальных значений, шт.'
    }
)

info_table
# Out:
#                      Тип данных Колл-во пропусков, шт. Колл-во пропусков, %  \
# total_images              int64                      0                    0
# last_price              float64                      0                    0
# total_area              float64                      0                    0
# first_day_exposition     object                      0                    0
# rooms                     int64                      0                    0
# ceiling_height          float64                   9195                   39
# floors_total            float64                     86                    0
# living_area             float64                   1903                    8
# floor                     int64                      0                    0
# is_apartment             object                  20924                   88
# studio                     bool                      0                    0
# ...

# %% [markdown]
# В первую очередь на данном этапе нас интересует количество пропусков по каждому из столбцов. Мы видим, что многие столбцы содержат пропуски, а в некоторых их колличество достигает 66%  по отношению к общему числу значений в столбце.

# %% [markdown]
# Оценим общий процент пропущенных значений.

# %%
print(round((data.isna().sum().sum() / data.size) * 100, 2), '%')
# Out:
# 19.46 %

# %% [markdown]
# Наконец построим гистограмму по каждому из столбцов, чтобы предварительно оценить наличие аномальных значений в данных.

# %%
data.hist(figsize=(15, 20), bins=50);

# %% [markdown]
# Видно, что данные не лишены аномальных значений, природу которых нам еще предстоит выяснить.

# %% [markdown]
# ### ОБЩИЕ ВЫВОДЫ ПО РАЗДЕЛУ 1

# %% [markdown]
# - В таблице представлено 22 столбца и 23699 строк. Все столбцы - ненулевые.
# - Названия столбцов были приведены к общепринятому стилю именования.
# - Каждая строка содержит данные об определенном жилом помещении, выставленном на продажу.
# - В данных содержатся пропуски и аномальные значения. Общее колличество пропущенных значений составляет 19.46%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно рассмотрел данные, с которыми предстоит работать.

# %% [markdown]
# ## ПРЕДОБРАБОТКА ДАННЫХ

# %% [markdown]
# Для удобства работы с данными нам понадобятся некоторые функции. Опишем далее действие каждой.

# %% [markdown]
# Функция `describe_column(df, column)` принимает 2 параметра: датафрейм и название столбца. Функция приводит описание характерных значений столбца. Если столбец сожержит численные значения, то функция дополнительно выводит возможные границы выбросов.

# %%
def describe_column(df, column):
    print(color.BOLD + 'Характерные значения:' + color.END, df[column].describe(), sep='\n', end='\n\n')
    print(color.BOLD + 'Колл-во пропусков:' + color.END, df[column].isna().sum(), end='\n\n')
    print(color.BOLD + 'Колл-во уникальных значений:' + color.END, df[column].nunique(), end='\n\n')
    
    if df[column].dtype == 'int' or df[column].dtype == 'float' and df[column].dtype != 'O':  
        q1 = df[column].quantile(0.25)
        q3 = df[column].quantile(0.75)
        lqr =  q3 - q1
        high_outlier = q3 + 1.5 * lqr
        low_outlier = q1 - 1.5 * lqr

        print(color.BOLD + 'Нижняя граница выбросов (Q1 - 1.5*lQR):' + color.END, round(low_outlier, 2), end='\n\n')
        print(color.BOLD + 'Верхняя граница выбросов (Q3 + 1.5*lQR):' + color.END, round(high_outlier, 2), end='\n\n')
        print(color.BOLD + 'Процентиль 5-ый:' + color.END, round(df[column].quantile(0.05), 2), end='\n\n')
        print(color.BOLD + 'Процентиль 95-ый:' + color.END, round(df[column].quantile(0.95), 2))

# %% [markdown]
# Функция `median_na_filling(na_column, group_column='')` предназначена для заполнения пропусков в столбце. При этом по умолчанию, если предедать функции только название столбца, функция заполнит пропуски медианном значением по этому столбцу. Если же передать функции дополнительный параметр `group_column`, то функция сгруппирует данные по столбцу `group_column` и посчитает медианные значения внутри каждой группы. Таким образом мы сможем более обоснованно заполнить пропущенные значения в некотором столбце.

# %%
def median_na_filling(na_column, group_column=''):
    if group_column == '':
        print(color.BOLD + 'Колл-во пропусков ДО заполнения:' + color.END, data[na_column].isna().sum())
        data.loc[data[na_column].isna(), na_column] = data[na_column].median()
        print(color.BOLD + 'Колл-во пропусков ПОСЛЕ заполнения:' + color.END, data[na_column].isna().sum())
    else:
        print(color.BOLD + 'Колл-во пропусков ДО заполнения:' + color.END, data[na_column].isna().sum())
        for value in data[group_column].unique():
            data.loc[(data[na_column].isna()) & (data[group_column] == value), na_column] = data.loc[data[group_column] == value, na_column].median()
        print(color.BOLD + 'Колл-во пропусков ПОСЛЕ заполнения:' + color.END, data[na_column].isna().sum())

# %% [markdown]
# Функция `outliers_elimination(df, column, low_outlier=0, high_outlier=0)` предназначена для фильтрации данных от аномальных значений. По умолчанию границы интервала наиболее вероятных значений определяются интервалом (Q1 - 1.5 * lQR, Q3 + 1.5 * lQR), где Q1 и Q3 - это первый и третий квартиль, а lQR - межквартильный размах. Также границы данного интервала можно задать вручную, передав функции соответствующие параметры `low_outlier, high_outlier`.

# %%
def outliers_elimination(df, column, low_outlier=0, high_outlier=0):
    if low_outlier == high_outlier == 0:
        q1 = df[column].quantile(0.25)
        q3 = df[column].quantile(0.75)
        lqr =  q3 - q1
        low_outlier = q1 - 1.5 * lqr
        high_outlier = q3 + 1.5 * lqr
        
    n_rows_before = df[column].count()
    print(color.BOLD + 'Колл-во строк в столбце ' + column + ' ДО удаления аномальных значений:' + color.END, n_rows_before, end='\n\n')

    df = df[(df[column] >= low_outlier) & (df[column] <= high_outlier)]

    n_rows_after = df[column].count()
    print(color.BOLD + 'Колл-во строк в столбце ' + column + ' ПОСЛЕ удаления аномальных значений:' + color.END, n_rows_after, end='\n\n')

    n_rows_deleted = round(((n_rows_before - n_rows_after) / n_rows_before ) * 100, 2)
    print(f"{color.BOLD}Колл-во удаленных аномальных значений:{color.END} {n_rows_before - n_rows_after} шт. ({n_rows_deleted} %)")
    return df

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Похвально, что используешь собственные функции для работы с данными.

# %% [markdown]
# ### Работа с артефактами в данных (пропущенные и аномальные значения, нарушения типов данных, устранение дубликатов)

# %% [markdown]
# Рассмотрим подробно каждый столбец таблицы в отдельности. На данном этапе наша задача:
# - Найти пропущенные значения в каждом столбце, изучить их природу, и заполнить пропущенные значения там, где это возможно.
# - Рассмотреть типы данных в каждом столбце. Найдите столбцы, в которых нужно изменить тип данных и выполнить преобразование.
# - Изучить уникальные значения в столбце с названиями и устранить неявные дубликаты.
# - Найти и устранить редкие и выбивающиеся значения.

# %% [markdown]
# Ключевыми для анализа являются столбцы, содержащие следующую информацию:
# - общая площадь
# - жилая площадь
# - площадь кухни
# - цена объекта
# - количество комнат
# - высота потолков
# - этаж квартиры
# - тип этажа квартиры («первый», «последний», «другой»)
# - общее количество этажей в доме
# - расстояние до центра города в метрах
# - расстояние до ближайшего аэропорта
# - расстояние до ближайшего парка
# - день и месяц публикации объявления
#
# Даныым столбцам уделим больше внимания.

# %% [markdown]
# #### Столбец 'total_images'

# %% [markdown]
# `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'total_images')
# Out:
# Характерные значения:
# count    23699.000000
# mean         9.858475
# std          5.682529
# min          0.000000
# 25%          6.000000
# 50%          9.000000
# 75%         14.000000
# max         50.000000
# Name: total_images, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 38
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -6.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 26.0
#
# Процентиль 5-ый: 1.0
#
# Процентиль 95-ый: 20.0

# %% [markdown]
# Тип данных столбца `float64` не соответствует типу его значений `int32`. Преобразуем тип столбца.

# %%
data['total_images'] = data['total_images'].astype('int32')
data['total_images'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# Построим гистограмму распределения значений столбца.

# %%
data['total_images'].hist(
    bins = 100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'total_images'",
    xlabel='Количество фотография в объявлении, шт.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# **Вывод**
#
# - Столбец `total_images` не содержит пропусков.
# - Мы привели тип данных столбца с `float64` к целочисленному типу `int32`.
#
# На гистограмме мы видим значение `total_images=20`, которое выбирается из распределения. Скорее всего сервис на момент получения данных позволял загрузить не более 20 фотографий. Значения больше 20 могут представлять собой ошибки в данных. Или можно было бы предположить, что на платных объявлениях колли-чество фотографий может быть большет 20.
#
# Ограничимся лишь приведенными предположениями и оставим данные столбца без изменений, поскольку значения данного столбца не являются существенными для анализа и не могут исказить никакие расчеты (или выводы), т.к. не участвуют в них.

# %% [markdown]
# #### Столбец 'last_price'

# %% [markdown]
# `last_price` — цена на момент снятия с публикации (руб.)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'last_price')
# Out:
# Характерные значения:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 2978
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -1700000.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 11900000.0
#
# Процентиль 5-ый: 1870000.0
#
# Процентиль 95-ый: 15300000.0

# %% [markdown]
# Построим гистограмму распределения значений столбца.

# %%
data['last_price'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'last_price'",
    xlabel='Цена недвижимости, руб.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Проверим, есть ли выбросы, свзязаные с низкими ценами. Построим гистограмму с диапазоне цен от 0 до 5-го процентиля.

# %%
data['last_price'].hist(
    range=(0, 1870000),
    bins=50,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'last_price'",
    xlabel='Цена недвижимости, руб.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Одно значение сильно выбиваетя из общего распределения. Отсортируем значения в столбце по цене, чтобы увидеть это знаение.

# %%
data['last_price'].sort_values().head(10)
# Out:
# 8793      12190.0
# 17456    430000.0
# 14911    430000.0
# 16274    440000.0
# 17676    450000.0
# 16219    450000.0
# 9581     450000.0
# 5698     450000.0
# 21912    470000.0
# 18867    470000.0
# Name: last_price, dtype: float64

# %%
data.loc[data.index == 8793]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7     12190.0       109.0  2019-03-20T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 8793            2.75          25.0         32.0     25          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# 8793          40.5      NaN  Санкт-Петербург           36421.0
#
#      city_centers_nearest  parks_around_3000  parks_nearest  \
# 8793               9176.0                1.0          805.0
#
#       ponds_around_3000  ponds_nearest  days_exposition
# 8793                0.0            NaN              8.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Скорее всего данный выброс связан с ошибкоьй в данных, и цену данного объявления следует домножить на 1000.

# %%
data.loc[8793, 'last_price'] = data.loc[8793, 'last_price'] * 1000
data.loc[8793, 'last_price']
# Out:
# 12190000.0

# %% [markdown]
# Проверим теперь ряд объявлений уже с менее подозрительной ценой, но все еще достаточно низкой.

# %%
data.loc[data['last_price'] == 430000]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 14911             5    430000.0        54.0  2018-06-26T00:00:00      2
# 17456             7    430000.0        30.4  2019-04-22T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 14911             NaN           3.0          NaN      3          NaN  ...
# 17456             NaN           2.0         16.0      1          NaN  ...
#
#        kitchen_area  balcony          locality_name  airports_nearest  \
# 14911           NaN      NaN  посёлок станции Свирь               NaN
# 17456           6.0      NaN                 Сланцы               NaN
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 14911                  NaN                NaN            NaN
# 17456                  NaN                NaN            NaN
#
#        ponds_around_3000  ponds_nearest  days_exposition
# 14911                NaN            NaN             44.0
# ...

# %% [markdown]
# Похоже, что в данных объявлениях ошибок нет.

# %% [markdown]
# Значения цен на квартиры будет проще восприниматать на графиках,если перевести их из рублей в млн. рублей. Сделаем это с округлением до десятков тысяч, чтобы не испортить объявления с самой низкой ценой.

# %%
data['last_price'] = data['last_price'] // 10000 / 100

# %%
describe_column(data, 'last_price')
# Out:
# Характерные значения:
# count    23699.000000
# mean         6.541484
# std         10.886916
# min          0.430000
# 25%          3.400000
# 50%          4.650000
# 75%          6.800000
# max        763.000000
# Name: last_price, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 1670
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -1.7
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 11.9
#
# Процентиль 5-ый: 1.87
#
# Процентиль 95-ый: 15.3

# %% [markdown]
# В данном столбце нет пропущенных значений. Характерные значения столбца и гистограмма их распределений свидетельствуют о том, что в данных присутствуют выбросы в диапазоне высоких цен на недвижимость. Посмотрим, какое колличество значений лежит за пределами верхней границы выбросов и что из себя представляют эти значения.

# %%
data[data['last_price'] > 11.9].sort_values(by='last_price', ascending=False).head(30)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12971            19      763.00       400.0  2017-09-30T00:00:00      7
# 19540             8      420.00       900.0  2017-12-06T00:00:00     12
# 14706            15      401.30       401.0  2016-02-20T00:00:00      5
# 1436             19      330.00       190.0  2018-04-04T00:00:00      3
# 15651            20      300.00       618.0  2017-12-18T00:00:00      7
# 22831            18      289.23       187.5  2019-03-19T00:00:00      2
# 16461            17      245.00       285.7  2017-04-10T00:00:00      6
# 13749             7      240.00       410.0  2017-04-01T00:00:00      6
# 5893              3      230.00       500.0  2017-05-31T00:00:00      6
# 8900             13      190.87       268.0  2016-03-25T00:00:00      3
# 19865            20      180.00       347.0  2015-01-21T00:00:00      8
# 19155            20      160.00       243.0  2018-11-12T00:00:00      5
# ...

# %% [markdown]
# Более 2000 строчек лежат за пределами верхней границы выбросов, что составляет около 9% от всех значений. Мы, конечно, могли бы предположить, что значения в приведенной выборке по ошибке умножены на 10, но наверняка окажемся неправы. Приведенная выборка объектов недвижимости представляет собой объекты элитного сектора с соответствующим ценообразованием. Математически/статистически подобные объекты не укладываются в интервал значений `(Q1 - 1.5*lQR; Q3 + 1.5*lQR)`, но верхняя граница в 11.9 млн. руб. представляется сильно заниженной. Даже значение 95-го процентиля , равное 15.3 млн. руб., все еще представляется заниженным.
#
# Поэтому мы будем постепенно фильтровать данные, пока не придём к удовлетворительному результату. На первом шаге ограничим верхнее значение цены на квартиру 100 млн. руб.

# %%
data = outliers_elimination(data, 'last_price', low_outlier=0, high_outlier=100)
# Out:
# Колл-во строк в столбце last_price ДО удаления аномальных значений: 23699
#
# Колл-во строк в столбце last_price ПОСЛЕ удаления аномальных значений: 23662
#
# Колл-во удаленных аномальных значений: 37 шт. (0.16 %)

# %% [markdown]
# Посмотрим на гистограмму после первого шага фильтрафии.

# %%
data['last_price'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'last_price'",
    xlabel='Цена недвижимости, млн. руб.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Теперь уже можно заметить, что значения выше примерно 25-30 млн. руб. имеют скорее единичный характер, поэтому могут быть спокойно исключены из рассмотрения.

# %% [markdown]
# Проверим, какое колличество значений мы отфильтруем, если исключим все строчки со значением `last_price` выше 25 млн.

# %%
outliers_elimination(data, 'last_price', low_outlier=0, high_outlier=25);
# Out:
# Колл-во строк в столбце last_price ДО удаления аномальных значений: 23662
#
# Колл-во строк в столбце last_price ПОСЛЕ удаления аномальных значений: 23235
#
# Колл-во удаленных аномальных значений: 427 шт. (1.8 %)

# %% [markdown]
# Мы полагаем, что подобная фильтрация является оптимальной в отношении имеющегося набора данных с точки зрения сохранения исходных данных.

# %%
data = outliers_elimination(data, 'last_price', low_outlier=0, high_outlier=25)
# Out:
# Колл-во строк в столбце last_price ДО удаления аномальных значений: 23662
#
# Колл-во строк в столбце last_price ПОСЛЕ удаления аномальных значений: 23235
#
# Колл-во удаленных аномальных значений: 427 шт. (1.8 %)

# %% [markdown]
# Построим теперь на график, отражающий форму распределения с его характерными значениями и выбросами.

# %%
data.boxplot(
    column='last_price',
    figsize=(11, 4)
).set(
    title='Выбросы значений, связанных с ценой на квартиру',
    ylabel='Цена недвижимости, млн. руб.'
);

# %% [markdown]
# Посмторим, как выглядит гистограмма значения цены недвижимости, а также как изменились характерные значения столбца после фильтрации.

# %%
data['last_price'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'last_price'",
    xlabel='Цена недвижимости, млн. руб.',
    ylabel='Количество значений, шт.'
);

# %%
describe_column(data, 'last_price')
# Out:
# Характерные значения:
# count    23235.000000
# mean         5.604139
# std          3.656483
# min          0.430000
# 25%          3.400000
# 50%          4.600000
# 75%          6.590000
# max         25.000000
# Name: last_price, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 1404
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -1.39
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 11.38
#
# Процентиль 5-ый: 1.85
#
# Процентиль 95-ый: 13.1

# %% [markdown]
# **Выводы**
#
# - Изучены значения столбца с ценой на наедвижимость.
# - В столбце отсутствуют пропущенные значения.
# - Исправлена ошибка, связанная с ценой на одну из квартир.
# - Определена верхняя граница выбросов для фильтрации данных.
#
# Цена на квартиру - весьма не симметричный параметр с точки зрения его распределения. Большая часть объявлений сосредоточена в диапазоне от 3.5 до 6.9 млн. руб. с медианной стоимостью квартиры в 4.8 млн. руб. На рынке присутствует  множество объявлений в сегменте этлитного жилья, цена которых достигает 763 млн. руб., но подобные объявления представляют скорее единичный характер. Проведенная фильтрация данных улучшела значение стандартного отколонения в выборке с `std=10.8` до `std=3.6`. Форма распределения также приняла более естественный для данного параметра характер.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что так подробно проводишь анализ прежде чем отбросить значения. Все сделал правильно.

# %% [markdown]
# #### Столбец 'total_area'

# %% [markdown]
# `total_area` — площадь квартиры в квадратных метрах (м²)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'total_area')
# Out:
# Характерные значения:
# count    23235.000000
# mean        57.615849
# std         26.603667
# min         12.000000
# 25%         40.000000
# 50%         51.200000
# 75%         68.000000
# max        460.800000
# Name: total_area, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 2002
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -2.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 110.0
#
# Процентиль 5-ый: 31.0
#
# Процентиль 95-ый: 106.0

# %% [markdown]
# Построим гистограмму распределения значений столбца.

# %%
data['total_area'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'total_area'",
    xlabel='Цена недвижимости, млн. руб.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Если мы вернемся к графикам и таблицам, полученными нами при первом знакомстве с данными, то увидим, что на гистограмме значений параметра `'total_area'` присутствуют аномально высокие значения. При этом приведенная выше гистограмма имеет уже другую форму. Это, очевидно, связано с тем, что на предыдущем этапе мы отфильтровали строчки с аномальными значениями цены недвижимости, а параметры цены и общей площади имеют прямую взаимосвязь. Таким образом выполнив фильтрацию по значениям цены мы также отфильтровали и значения общей площади.

# %% [markdown]
# Тем не менее приведенные данные могут поребовать дополнительной фильтрации. Рассмотрим значения площади в диапазоне низких значений.

# %%
data['total_area'].hist(
    range=(12, 40),
    bins=30,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'total_area' < 40 кв.м.",
    xlabel='Площадь объекта недвижимости, кв.м.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Площадь некоторых квартир/аппартоментов находится ниже 25 кв.м. Посмотрим, что это за квартиры.

# %%
data[data['total_area'] < 25].sort_values(by='total_area')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19904             4        2.40        12.0  2017-07-19T00:00:00      1
# 19807             0        3.80        13.0  2018-07-04T00:00:00      1
# 19546             3        1.85        13.0  2019-03-11T00:00:00      1
# 17961             3        1.40        13.0  2017-12-03T00:00:00      1
# 19558             2        1.68        13.2  2018-12-17T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 9579              9        3.45        24.8  2019-02-01T00:00:00      0
# 20757             3        2.21        24.8  2017-10-26T00:00:00      1
# 23579             7        2.35        24.8  2018-06-07T00:00:00      1
# 13471            15        3.35        24.9  2018-03-21T00:00:00      0
# 18190             3        3.32        24.9  2018-03-06T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Теперь посмотрим на высокие значение площади квартиры.

# %%
data[data['total_area'] > 170].sort_values(by='total_area')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23181            20       22.22       170.7  2019-02-12T00:00:00      4
# 9448              3       21.32       170.9  2015-11-06T00:00:00      4
# 16266            14       20.80       171.0  2018-03-27T00:00:00      3
# 5711             17       18.00       171.0  2017-06-16T00:00:00      7
# 3352             20       15.50       171.0  2015-08-25T00:00:00      5
# ...             ...         ...         ...                  ...    ...
# 9550             10       23.50       313.0  2017-02-13T00:00:00      9
# 11436             4       24.00       316.3  2015-03-25T00:00:00      8
# 11087             3       14.00       320.0  2017-09-27T00:00:00      6
# 866               5       25.00       363.0  2017-12-23T00:00:00     14
# 20273            12       20.00       460.8  2019-03-20T00:00:00      6
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data = outliers_elimination(data, 'total_area', low_outlier=20, high_outlier=160);
# Out:
# Колл-во строк в столбце total_area ДО удаления аномальных значений: 23235
#
# Колл-во строк в столбце total_area ПОСЛЕ удаления аномальных значений: 23012
#
# Колл-во удаленных аномальных значений: 223 шт. (0.96 %)

# %% [markdown]
# Посмторим на гистограмму значений общей площади после фильтрации значений.

# %%
data['total_area'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'total_area'",
    xlabel='Площадь объекта недвижимости, кв.м.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# **Вывод**
#
# - Аномальные значения площади ниже 25 кв.м. и выше 160 кв.м. в количестве 174 шт. были отфильтрованы.
# - Других проблем со значениями в столбце `total_area` не выявлено.
#
# Наиболее типичные значения площади квартир для данной выборки лежат в диапазоне от 40 до 68 кв.м.

# %% [markdown]
# #### Столбец 'first_day_exposition'

# %% [markdown]
# `first_day_exposition` — дата публикации

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'first_day_exposition')
# Out:
# Характерные значения:
# count                   23012
# unique                   1487
# top       2018-02-01T00:00:00
# freq                      360
# Name: first_day_exposition, dtype: object
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 1487

# %% [markdown]
# Столбец имеет тип `object`, но значения столбца хранят дату и время пуликации объявления. Изменим формат данных столбца на корректный.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data['first_day_exposition'].head()
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 4   2018-06-19
# 5   2018-09-10
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# **Выводы**
# - Данные в столбце были приведены к корректному формату `datetime64[ns]`.
# - Других проблем со значениями в столбце не вывлено.

# %% [markdown]
# #### Столбец 'rooms'

# %% [markdown]
# `rooms` — число комнат

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'rooms')
# Out:
# Характерные значения:
# count    23012.000000
# mean         2.002651
# std          0.956778
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          8.000000
# Name: rooms, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 9
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -2.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 6.0
#
# Процентиль 5-ый: 1.0
#
# Процентиль 95-ый: 4.0

# %% [markdown]
# Данные о количестве комнат хранятся в формате `float64`, но предполагают целочисленный формат. Преобразуем данные к целочисленному формату.

# %%
data['rooms'] = data['rooms'].astype('int')

# %% [markdown]
# Построим круговую диаграмму долей квартир в зависимости от количества комнат.

# %%
data.pivot_table(index='rooms', values='total_area', aggfunc='count').plot.pie(
    subplots=True,
    figsize=(8, 8),
    autopct="%.1f",
    fontsize=12,
    title='Доля квартир в зависимости от количества комнат'
);

# %% [markdown]
# Построим гистограмму распределения значений столбца.

# %%
data['rooms'].hist(
    bins=30,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'rooms'",
    xlabel='Количество комнат, шт.',
    ylabel='Количество значений, шт.'
);

# %%
data.pivot_table(index='rooms', values='total_area', aggfunc='count')
# Out:
#        total_area
# rooms
# 0             188
# 1            8019
# 2            7903
# 3            5643
# 4            1021
# 5             193
# 6              34
# 7              10
# 8               1

# %% [markdown]
# На гистограмме мы видим, что есть объявления, в которых указано нулевое колличество комнат. Можно предположить, что эти объявления могут быть связаны либо с апартаментами, либо с открытой планировкой.

# %%
data[data['rooms'] == 0][['rooms', 'open_plan', 'is_apartment']].count()
# Out:
# rooms           188
# open_plan       188
# is_apartment      5
# dtype: int64

# %% [markdown]
# Действительно, все 196 значений `rooms = 0` связаны открытой планировкой.

# %% [markdown]
# Посмотрим детальнее, сколько объявлений по каждому типу квартир (1-комнатной, 2-комнатной, и т.д.)

# %%
data['rooms'].value_counts()
# Out:
# 1    8019
# 2    7903
# 3    5643
# 4    1021
# 5     193
# 0     188
# 6      34
# 7      10
# 8       1
# Name: rooms, dtype: int64

# %% [markdown]
# Удалим объявления, в которых колличество комнат превышает 6.

# %%
data = outliers_elimination(data, 'rooms', low_outlier=0, high_outlier=6).sort_values(by='rooms', ascending=False)
# Out:
# Колл-во строк в столбце rooms ДО удаления аномальных значений: 23012
#
# Колл-во строк в столбце rooms ПОСЛЕ удаления аномальных значений: 23001
#
# Колл-во удаленных аномальных значений: 11 шт. (0.05 %)

# %% [markdown]
# **Выводы**
#
# - Проблем с пропусками не выявлено.
# - Преобразовали данные столбца `rooms` к целочисленному формату.
# - Исключили из таблицы строки с количеством комнаты больше 6.
#
# Здесь без сюрпризов. Подавляющая часть квартир, выствленных на продажу - это "однушки", "двушки", и "трёшки". Больше всего - однокомнатных и двухкомнатных, их колличество примерно одинаковое и составляет 6817 шт. и 6481 шт. соответственно. Трехкомнатных квартир уже меньше, их 4662 шт. Всех остальных квартир - немногим больше 1000 шт. В эту категорию входят квартиры с 4, 5, 6 комнатами, и квартиры с открытой планировкой, в которых колличество комнат указано равным 0.

# %% [markdown]
# #### Столбец 'ceiling_height'

# %% [markdown]
# `ceiling_heigh` — высота потолков (м)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'ceiling_height')
# Out:
# Характерные значения:
# count    14038.000000
# mean         2.756646
# std          1.276473
# min          1.000000
# 25%          2.500000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64
#
# Колл-во пропусков: 8963
#
# Колл-во уникальных значений: 168
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): 2.05
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 3.25
#
# Процентиль 5-ый: 2.5
#
# Процентиль 95-ый: 3.2

# %% [markdown]
# Построим гистограмму распределения значений столбца.

# %%
data['ceiling_height'].hist(
    bins=30,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'ceiling_height'",
    xlabel='Высота потолков, м.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# В столбце присутствуют пропуски в количестве чуть меньше 9000 шт., а также вылетающие значения. Прежде чем заполнить пропуски, избавимся от вылетающих значений. Посмотрим, какие максимальные значения присутствуют в данных.

# %%
data['ceiling_height'].dropna().sort_values().tail(25)
# Out:
# 22309     10.3
# 15061     14.0
# 17496     20.0
# 20507     22.6
# 5076      24.0
# 355       25.0
# 11285     25.0
# 9379      25.0
# 18545     25.0
# 4643      25.0
# 14382     25.0
# 6246      25.0
# 5669      26.0
# 5807      27.0
# 21824     27.0
# 22938     27.0
# 17857     27.0
# 10773     27.0
# 20478     27.0
# 5246      27.0
# 4876      27.0
# 21377     27.5
# 3148      32.0
# 22336     32.0
# 22869    100.0
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Можно предположить, что значения (25 м, 27 м, ... , 32 м) на самом деле представляют собой вещественные значения (2.5 м, 2.7 м, ... , 3.2 м).

# %%
data[(data['ceiling_height'] >= 25) & ((data['ceiling_height'] <= 32))]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22938            14        4.00        98.0           2018-03-15      4
# 17857             1        3.90        56.0           2017-12-22      3
# 9379              5        3.95        42.0           2017-03-26      3
# 3148             14        2.90        75.0           2018-11-12      3
# 21824            20        2.45        44.0           2019-02-12      2
# 22336            19        9.99        92.4           2019-04-05      2
# 18545             6        3.75        43.0           2019-03-18      2
# 5669              4        4.40        50.0           2017-08-08      2
# 5807             17        8.15        80.0           2019-01-09      2
# 6246              6        3.30        44.4           2019-03-25      2
# 5246              0        2.50        54.0           2017-10-13      2
# 355              17        3.60        55.2           2018-07-12      2
# ...

# %% [markdown]
# Исправим эти значения.

# %%
data.loc[(data['ceiling_height'] >= 25) & ((data['ceiling_height'] <= 32)), 'ceiling_height'] = \
data.loc[(data['ceiling_height'] >= 25) & ((data['ceiling_height'] <= 32)), 'ceiling_height'] / 10

# %% [markdown]
# Пропуски в столбце `ceiling_height` заполним медианными значениями данных, сгруппированных по значниям столбца `rooms`.

# %%
data.pivot_table(index='rooms', values='ceiling_height', aggfunc='median')
# Out:
#        ceiling_height
# rooms
# 0                2.70
# 1                2.64
# 2                2.60
# 3                2.65
# 4                2.75
# 5                3.01
# 6                3.10

# %%
median_na_filling('ceiling_height', 'rooms')
# Out:
# Колл-во пропусков ДО заполнения: 8963
# Колл-во пропусков ПОСЛЕ заполнения: 0

# %% [markdown]
# Теперь исключим вылетающие значения. Высота потолков в жилых помещениях должна быть не менее 2.5 м. Верхнее значение ограничим 3.6 м.

# %%
data = outliers_elimination(data, 'ceiling_height', low_outlier=2.5, high_outlier=3.6);
# Out:
# Колл-во строк в столбце ceiling_height ДО удаления аномальных значений: 23001
#
# Колл-во строк в столбце ceiling_height ПОСЛЕ удаления аномальных значений: 22773
#
# Колл-во удаленных аномальных значений: 228 шт. (0.99 %)

# %% [markdown]
# Посмотрим, как изменились характерные значения столбца после заполнения пропусков и фильтрации данных.

# %%
describe_column(data, 'ceiling_height')
# Out:
# Характерные значения:
# count    22773.000000
# mean         2.674388
# std          0.176052
# min          2.500000
# 25%          2.600000
# 50%          2.640000
# 75%          2.700000
# max          3.600000
# Name: ceiling_height, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 106
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): 2.45
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 2.85
#
# Процентиль 5-ый: 2.5
#
# Процентиль 95-ый: 3.01

# %% [markdown]
# **Выводы**
#
# - Данные столбца `ceiling_height` содержали немногим меньше 9000 пропущенных значений. Полученные пропуски удалось заполнить путем группировки значений по столбцу `rooms` и расчета медианного значения `ceiling_height` внутри каждой группы.
# - Часть данных содержала ошибки: были обнаружены значения 25 м, 27 м, ... , 32 м. Данные значения были поделены на 10 и сохранены.
# - Вылетающими были определены значения `ceiling_height` ниже 2.5 м, и выше 3.6 м.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно обработал. Можно было отдельно рассмотреть с какими параметрами больше всего коррелирует высота потолков, количество комнат определенно играет роль на высоту потолков. Логично, что расстояние до центра тоже оказывает влияние на высоту потолка, ближе к центру города больше исторических построек, у них средняя высота потолков выше, чем у домов, которые строятся дальше от центра.

# %% [markdown]
# #### Столбец 'floors_total'

# %% [markdown]
# `floors_total` — всего этажей в доме

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'floors_total')
# Out:
# Характерные значения:
# count    22688.000000
# mean        10.804258
# std          6.635514
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64
#
# Колл-во пропусков: 85
#
# Колл-во уникальных значений: 35
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -11.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 32.5
#
# Процентиль 5-ый: 4.0
#
# Процентиль 95-ый: 25.0

# %%
data['floors_total'].hist(
    bins=70,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'floors_total'",
    xlabel='Этажность здания',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Столбец `floors_total` содержат 85 пропущенных значений, а также небольшое количество аномально высоких значений.

# %%
data[data['floors_total'].isna()==True]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 14264            13       14.00       94.00           2019-01-23      6
# 10880             5       11.99      147.70           2017-06-23      5
# 6030              3       10.90      116.23           2017-05-05      4
# 10351             4        5.38      110.72           2015-10-09      4
# 15989             1        4.10       74.50           2017-04-22      3
# ...             ...         ...         ...                  ...    ...
# 16496             1        5.23       38.20           2016-04-01      1
# 16591             8        4.50       37.60           2018-07-10      1
# 5187              5        3.30       25.40           2018-11-02      0
# 4901              5        2.20       24.00           2018-10-22      0
# 5958              1        3.20       30.30           2018-09-07      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Никаких видимых закономерностей, обуславливающих отсутствие значений столбца `floors_total` не было обнаружено, отсутствующие 85 значений было принято исключить.

# %%
data = data.dropna(subset=['floors_total'])
data['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Верное решение, так держать!

# %% [markdown]
# Также данные о количестве этажей хранятся в формате `float64`, но предполагают целочисленный формат. Преобразуем данные к целочисленному формату.

# %%
data['floors_total'] = data['floors_total'].astype('int')
data['floors_total'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Теперь посмотрим на все значения и на их количество. Проверим, нет ли в таблице значений `floors_total = 0`, а также определим верхнюю границу вылетающих значений.

# %%
data['floors_total'].value_counts()
# Out:
# 5     5559
# 9     3710
# 16    1348
# 12    1331
# 10    1147
# 4     1094
# 25    1070
# 17     820
# 6      778
# 3      624
# 14     543
# 7      515
# 18     495
# 24     468
# 2      358
# 15     351
# 23     346
# 19     328
# 8      319
# 22     285
# 20     263
# 13     224
# 11     191
# 27     164
# 21     158
# 26     123
# 35      24
# 1       23
# 28      21
# 36       3
# 33       1
# 60       1
# 29       1
# 34       1
# 52       1
# Name: floors_total, dtype: int64

# %% [markdown]
# Исключим из данных значения выше 27.

# %%
data = outliers_elimination(data, 'floors_total', low_outlier=1, high_outlier=27);
# Out:
# Колл-во строк в столбце floors_total ДО удаления аномальных значений: 22688
#
# Колл-во строк в столбце floors_total ПОСЛЕ удаления аномальных значений: 22635
#
# Колл-во удаленных аномальных значений: 53 шт. (0.23 %)

# %% [markdown]
# Посмотрим на гистограмму значений.

# %%
data['floors_total'].hist(
    bins=70,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'floors_total'",
    xlabel='Этажность здания',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# **Выводы**
#
# - Тип данных столбца `floors_total` был изменен на целочисленный.
# - В данных были обнаружены пропуски в количестве 85 шт. Эти значения были исключены из данных.
# - Значения выше 27 в количестве 53 шт. также было принято исключить.
#
# Больше всего на рынке объявлений о продаже квартир в "пятиэтажках", их 5589 шт. Чуть менее популярны - "девятиэтажки", которые представляют собой медианное значение по выборке, их 3713 шт. Интересно, что достаточно много объявлений о продаже квартир в 25-этажных домах, их насчитывается 1070 шт. Почти столько же объявлений для четырехэтажных домах - 1094 шт.

# %% [markdown]
# #### Столбец 'living_area'

# %% [markdown]
# `living_area` — жилая площадь в квадратных метрах (м²)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'living_area')
# Out:
# Характерные значения:
# count    20868.000000
# mean        32.168931
# std         15.364149
# min          2.000000
# 25%         18.500000
# 50%         30.000000
# 75%         41.100000
# max        128.000000
# Name: living_area, dtype: float64
#
# Колл-во пропусков: 1767
#
# Колл-во уникальных значений: 1518
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -15.4
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 75.0
#
# Процентиль 5-ый: 15.2
#
# Процентиль 95-ый: 60.4

# %% [markdown]
# Построим гистограмму распределения значений столбца.

# %%
data['living_area'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'living_area'",
    xlabel='Жилая площадь, кв.м.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Данные столбца `living_area` содержат 1768 пропущенных значений. Также наблюдаются вылетающие значения, и ярко выраженный локальный максимум в районе 18 кв.м.

# %% [markdown]
# Можно предположить, что отсутствующие значения жилой площади могут быть связаны со свободной планировкой.

# %%
data[data['open_plan'] == True][['living_area', 'open_plan']]
# Out:
#        living_area  open_plan
# 19796         71.3       True
# 14017         37.6       True
# 8861          48.0       True
# 12760         30.0       True
# 1379          17.4       True
# ...            ...        ...
# 6472          18.0       True
# 4876          17.0       True
# 3019          18.0       True
# 17805         21.4       True
# 20054         14.0       True
#
# [63 rows x 2 columns]

# %% [markdown]
# Исходя из приведенной выше таблицы, отсутствующие значения жилой площади не связаны со свободной планировкой. Заполним имеющиеся пропуски, основываясь на соотношении данных жилой и полной площади. Введем масштабный коэффициент, который будет переводить значение полной площади `total_area` в значения жилой площади `living_area`.

# %%
# Масштабный коэффициент living_area_scalar переводит значения
# полной площади total_area в значения жилой площади living_area
living_area_scalar = data['living_area'].median() / data['total_area'].median()

data.loc[data['living_area'].isna(), 'living_area'] = \
data.loc[data['living_area'].isna(), 'total_area'] * living_area_scalar

data['living_area'] = round(data['living_area'], 1)
data[['living_area', 'total_area']]
# Out:
#        living_area  total_area
# 9856          70.0      106.00
# 23094        108.8      155.80
# 18548         86.2      119.00
# 23047         75.0      110.00
# 5255          68.0       87.00
# ...            ...         ...
# 10729         17.4       28.00
# 15319         28.2       43.30
# 17805         21.4       31.10
# 20054         14.0       21.00
# 14535         16.7       24.05
#
# [22635 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличное решение заполнить пропуски с помощью коэффициента отношения к общей площади. Перед тем как такой метод использовать, логично было бы проверить как эти случайные величины коррелируют друг с другом.

# %% [markdown]
# Проверим, что все пропуси были заполнены.

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Теперь проверим, что предложенный метод заполнения пропусков не привел к искажению характера распределения значений столбца `living_area`.

# %%
data['living_area'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'living_area'",
    xlabel='Жилая площадь, кв.м.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Теперь искоючим вылетающие значения. Построим график типа "boxplot".

# %%
data.boxplot(
    column='living_area',
    figsize=(11, 4)).set(
    title='Выбросы значений, связанных с размером жилой площади',
    ylabel='Жилая площадь, кв.м.',
);

# %% [markdown]
# Посмторим детальнее на гистограмму в диапазоне значений от 0 до 15 кв.м.

# %%
data['living_area'].hist(
    range=(0, 15),
    bins=30,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'living_area' < 15 кв.м.",
    xlabel='Жилая площадь, кв.м.',
    ylabel='Количество значений, шт.'
);

# %%
data['living_area'].sort_values()
# Out:
# 21758      2.0
# 13915      2.0
# 3242       3.0
# 17582      5.0
# 21943      5.4
#          ...
# 12371    117.1
# 12234    118.5
# 13344    122.1
# 1067     125.0
# 18164    128.0
# Name: living_area, Length: 22635, dtype: float64

# %% [markdown]
# Исключим единичные вылеты ниже 10 кв.м. и выше 100 кв.м.

# %%
data = outliers_elimination(data, 'living_area', low_outlier=10, high_outlier=80);
# Out:
# Колл-во строк в столбце living_area ДО удаления аномальных значений: 22635
#
# Колл-во строк в столбце living_area ПОСЛЕ удаления аномальных значений: 22347
#
# Колл-во удаленных аномальных значений: 288 шт. (1.27 %)

# %% [markdown]
# **Выводы**
#
# - В данных было обнаружено более 1700 пропущенных значений, которые вопреки нашим предположениям не были связаны с открытым типом планировки.
# - Пропущенные значения были заполнены опираясь на данные об общей площади квартиры и ее умножения на масштабный коэффициент, посчитанный путем медианного осреднения значений жилой и общей площади и деления одного на другое.
# - Исключили единичные вылетающие значения ниже 10 кв.м. и выше 80 кв.м.
#
#
# После фильтрации данных на гистограмме значений паараметра `living_area` мы видим 2 острых и один менее выраженных пик. Вероятнее всего эти пики связаны с наиболее популярными видами квартир - одно-, двух-, и трехкомнатными квартирами. Ранее при анализа столбца `floors_total` мы видели, что большая часть домов, в которых продаются квартиры - это "пятиэтажки" с типовыми планировками. Современное жилье уже имеет больше разнообразие планировок, поэтому именно типовые планировки в старых домах и создают выраженные пики на гистограмме.

# %% [markdown]
# #### Столбец 'floor'

# %% [markdown]
# `floor` — этаж

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'floor')
# Out:
# Характерные значения:
# count    22347.000000
# mean         5.903790
# std          4.874461
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         27.000000
# Name: floor, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 27
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -7.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 17.0
#
# Процентиль 5-ый: 1.0
#
# Процентиль 95-ый: 16.0

# %% [markdown]
# Данные об этаже хранятся в формате `float64`, но предполагают целочисленный формат. Преобразуем данные к целочисленному формату.

# %%
data['floor'] = data['floor'].astype('int')
data['floor'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Построим гистограмму распределения значений столбца.

# %%
data['floor'].hist(
    bins=66,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'floor'",
    xlabel='Этаж',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# **Выводы**
# - Значения в столбце `floor` были приведены к целочисленному формату.
# - Других проблем, связанных с пропущенными, вылетающими, или некорректно заданными значениями в столбце обнаружено не было.
#
# Больше всего продается квартир в дианазоне от 1 до 8 этажа, что обусловлено преобладанием пятиэтажных и десятиэтажных домов. На гистограмме отчетливо видно разделение группы от 1 до 5, и от 6 до 10 этажа.

# %% [markdown]
# #### Столбец 'is_apartment'

# %% [markdown]
# `is_apartment` — апартаменты (булев тип)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'is_apartment')
# Out:
# Характерные значения:
# count      2613
# unique        2
# top       False
# freq       2576
# Name: is_apartment, dtype: object
#
# Колл-во пропусков: 19734
#
# Колл-во уникальных значений: 2

# %% [markdown]
# В столбце `is_apartment` обнаружено почти 20 тыс. пропущенных значений.

# %%
data[data['is_apartment'] == False]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 16857            10        8.40       125.0           2018-12-05      5
# 17753            12        1.80       117.3           2016-02-18      5
# 15999            16        8.50        84.0           2016-03-15      5
# 9419              9        5.78        99.0           2019-03-29      5
# 21417            17       10.45       109.3           2019-02-25      5
# ...             ...         ...         ...                  ...    ...
# 839              14        1.90        35.0           2017-04-14      0
# 4930              6        2.17        23.0           2017-12-08      0
# 7256             16        3.50        29.2           2017-04-16      0
# 10534            10        2.10        26.7           2018-08-03      0
# 20584            12        2.17        22.2           2018-11-04      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Отделить квартиры от апартоментов по очевидному признаку - площадь квартиры, также невозможно. Мы проверили, что на рынке объявлений присутствуют квартиры с площадью менее 20 кв.м. Оснований для заполнения пропусков значениями 'True' у нас нет, т.к. выделить по каким-то косвенным признакам аппартаменты не представляется возможным. Единтсвенный вариант - заполнить пропуски значением False, т.к. это наиболее распространенный вид жилых помещений. Косвенным аргументом может служить то, что аппартаменты - явление сравнительно новое и присутствует в достаточно современных домах. Посколько в последние десятилетия этажность застройки домов достаточно высокая, то наличие апартаментов стоит ожидать в высокоэтажных домах, каких в нашей выборке достаточно мало. Преобладающая этажность домов лежит в диапазоне до 10 этажей, а больше всего объявлений - в пятиэтажках.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# Теперь преобразуем тип данных к корректному, т.к. значения типа `object` не соответствует булевым значениям столбца.

# %%
data['is_apartment'] = data['is_apartment'].astype('bool')
data['is_apartment'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# **Выводы**
#
# - Значения столбца приведены к логическому типу `bool`.
# - В столбце `is_apartment` было обнаружено почти 20 тыс. пропусокв. Пропуски  были заполнены значением `False`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Когда ты изменил тип столбца на bool пропуски автоматически заполнились значениями True, поэтому пропуски нужно заполнить перед тем, как изменять тип данных.

# %% [markdown]
# <div style="border:solid black 2px; padding: 40px">
#     Понял, исправил :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно изменил. Чтобы такого не возникало лучше проверять какие значения были до обработки, и какие стали после.

# %% [markdown]
# #### Столбец 'studio'

# %% [markdown]
# `studio` — квартира-студия (булев тип)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'studio')
# Out:
# Характерные значения:
# count     22347
# unique        2
# top       False
# freq      22212
# Name: studio, dtype: object
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 2

# %% [markdown]
# Тип данных `object` не соответствует булевым знаениям столбца. Преобразуем тип данных к корректному.

# %%
data['studio'] = data['studio'].astype('bool')
data['studio'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# **Выводы**
#
# - Значения столбца приведены к логическому типу `bool`.
# - Других проблем c данными в столбце не выявлено.

# %% [markdown]
# #### Столбец 'open_plan'

# %% [markdown]
# Посмторим на характерные значение столбца.

# %% [markdown]
# `open_plan` — свободная планировка (булев тип)

# %%
describe_column(data, 'open_plan')
# Out:
# Характерные значения:
# count     22347
# unique        2
# top       False
# freq      22284
# Name: open_plan, dtype: object
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 2

# %% [markdown]
# Тип данных `object` не соответствует булевым знаениям столбца. Преобразуем тип данных к корректному.

# %%
data['open_plan'] = data['open_plan'].astype('bool')
data['open_plan'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# **Выводы**
#
# - Значения столбца приведены к логическому типу `bool`.
# - Других проблем c данными в столбце не выявлено.

# %% [markdown]
# #### Столбец 'kitchen_area'

# %% [markdown]
# `kitchen_area` — площадь кухни в квадратных метрах (м²)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'kitchen_area')
# Out:
# Характерные значения:
# count    20260.000000
# mean        10.042287
# std          4.707115
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.400000
# max         65.000000
# Name: kitchen_area, dtype: float64
#
# Колл-во пропусков: 2087
#
# Колл-во уникальных значений: 875
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): 0.4
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 18.0
#
# Процентиль 5-ый: 5.5
#
# Процентиль 95-ый: 17.9

# %%
data['kitchen_area'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'kitchen_area'",
    xlabel='Площадь кухни, кв.м.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# В столбце `kitchen_area` обнаружены пропуски. Заполним эти пропуски аналогично тому, как мы заполняли пропуски в столбце `living_area`, т.е. расчитаем масштабный коэффициент, который будет приводить значения столбца `total_area` к значениям `kitchen_area`.

# %%
# рассчитаем медианные значения по столбцам 'total_area' и 'kitchen_area'
median_total_area = data['total_area'].median()
median_kitchen_area = data['kitchen_area'].median()

kitchen_area_scalar = median_kitchen_area / median_total_area
kitchen_area_scalar
# Out:
# 0.17786561264822134

# %% [markdown]
# Умножим значения столбца `total_area` на рассчитанный мастабный коэффициент `kitchen_area_scalar`.

# %%
data.loc[data['kitchen_area'].isna(), 'kitchen_area'] = \
data.loc[data['kitchen_area'].isna(), 'total_area'] * kitchen_area_scalar
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Удалим единичные выбросы. Посмотрим на график с вылетами.

# %%
data.boxplot(
    column='kitchen_area',
    figsize=(11, 4)).set(
    title='Выбросы значений, связанных с площадью кухни',
    ylabel='Площадь кухни, кв.м.'
);

# %%
data = outliers_elimination(data, 'kitchen_area', low_outlier=3, high_outlier=20);
# Out:
# Колл-во строк в столбце kitchen_area ДО удаления аномальных значений: 22347
#
# Колл-во строк в столбце kitchen_area ПОСЛЕ удаления аномальных значений: 21672
#
# Колл-во удаленных аномальных значений: 675 шт. (3.02 %)

# %%
describe_column(data, 'kitchen_area')
# Out:
# Характерные значения:
# count    21672.000000
# mean         9.398224
# std          3.189900
# min          3.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.000000
# max         20.000000
# Name: kitchen_area, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 1248
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): 1.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 17.0
#
# Процентиль 5-ый: 5.3
#
# Процентиль 95-ый: 15.57

# %% [markdown]
# **Выводы**
#
# - В данных было обнаружено немногим больше 2000 пропущенных значений.
# - Пропущенные значения были заполнены опираясь на данные об общей плщади квартиры и ее умножения на масштабный коэффициент, посчитанный путем медианного осреднения значений площади кухни и общей площади, и деления одного на другое.
# - Исключили единичные вылетающие значения ниже 3 кв.м. и выше 30 кв.м.
#
# Медианное значение площиди кухни получилось равным 9 кв.в., что очень похоже на правду.

# %% [markdown]
# #### Столбец 'balcony'

# %% [markdown]
# `balcony` — число балконов

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'balcony')
# Out:
# Характерные значения:
# count    11257.000000
# mean         1.152971
# std          1.052655
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          5.000000
# Name: balcony, dtype: float64
#
# Колл-во пропусков: 10415
#
# Колл-во уникальных значений: 6
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -3.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 5.0
#
# Процентиль 5-ый: 0.0
#
# Процентиль 95-ый: 2.0

# %%
data['balcony'].hist(
    bins=12,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'balcony'",
    xlabel='Количество балконов, шт.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# В данных столбца `balcony` обнаружены пропущенные значение, которые вероятнее всего связаны с отсутствием балкона в квартире, и как следствие, не заполнение пользователем данного поля. Заполним пропущенные значения.

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# Тип данных `object` не соответствует булевым знаениям столбца. Преобразуем тип данных к корректному.

# %%
data['balcony'] = data['balcony'].astype('int')
data['balcony'].dtype
# Out:
# dtype('int64')

# %%
data['balcony'].hist(
    range=(3,5),
    bins=12,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'balcony' в диапазоне от 3 до 3",
    xlabel='Количество балконов, шт.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Любопытно, что квартир с тремя балконами меньше, чем с четырмя, а квартир с четырмя балконам меньше, чем с пятью.

# %% [markdown]
# Посчитаем процент квартир, у которых есть балкон.

# %%
data[data['balcony'] != 0].count()['balcony'] / data.count()['balcony']
# Out:
# 0.36263381321520854

# %%
describe_column(data, 'balcony')
# Out:
# Характерные значения:
# count    21672.000000
# mean         0.598883
# std          0.952571
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: balcony, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 6
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -1.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 2.5
#
# Процентиль 5-ый: 0.0
#
# Процентиль 95-ый: 2.0

# %% [markdown]
# **Выводы**
#
# - Значения столбца приведены к логическому типу `bool`.
# - В столбце `balcony` было обнаружены пропусоки в колличестве более 10 тыс.
# - Вероятнее всего пропуски связаны с отсутствием балконов и заполнены значением 0.
# - Других проблем со значениями в столбце `balcony` не выявлено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все остальные параметры обработал абсолютно верно, продолжай в том же духе!

# %% [markdown]
# #### Столбец 'locality_name'

# %% [markdown]
# `locality_name` — название населённого пункта

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'locality_name')
# Out:
# Характерные значения:
# count               21630
# unique                360
# top       Санкт-Петербург
# freq                13967
# Name: locality_name, dtype: object
#
# Колл-во пропусков: 42
#
# Колл-во уникальных значений: 360

# %% [markdown]
# В данных обнаружены пропуски. Поскольку выделить по каким-то косвенным признакам название населенного пункта не представляется возможным, у нас нет оснований для заполнения пропусков какими-либо значениями. Исключим данные пропуски из рассмотрения.

# %%
data = data.dropna(subset=['locality_name']).reset_index(drop=True)

# %% [markdown]
# Теперь проверим данные на неявные дубликаты. Посмотрим на уникальные значения, отсортированные в алфавитном порядке.

# %%
sorted(data['locality_name'].unique())
# Out:
# ['Бокситогорск',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Высоцк',
#  'Гатчина',
#  'Зеленогорск',
#  'Ивангород',
#  'Каменногорск',
#  'Кингисепп',
#  'Кириши',
#  'Кировск',
#  'Колпино',
#  'Коммунар',
#  'Красное Село',
#  'Кронштадт',
#  'Кудрово',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Луга',
#  'Любань',
#  'Мурино',
#  'Никольское',
#  'Новая Ладога',
#  'Отрадное',
#  'Павловск',
#  'Петергоф',
#  'Пикалёво',
#  'Подпорожье',
#  'Приморск',
#  'Приозерск',
#  'Пушкин',
#  'Санкт-Петербург',
#  'Светогорск',
#  'Сертолово',
#  'Сестрорецк',
#  'Сланцы',
#  'Сосновый Бор',
#  'Сясьстрой',
#  'Тихвин',
#  'Тосно',
#  'Шлиссельбург',
#  'городской поселок Большая Ижора',
#  'городской поселок Янино-1',
#  'городской посёлок Будогощь',
#  'городской посёлок Виллози',
#  'городской посёлок Лесогорский',
#  'городской посёлок Мга',
#  'городской посёлок Назия',
#  'городской посёлок Новоселье',
#  'городской посёлок Павлово',
#  'городской посёлок Рощино',
# ...

# %% [markdown]
# Дубликаты в названиях населенного пункта связаны с наличием/отсутствием указания типа населенного пункта (поселок, деревня, и т.д.), а также с их различным написанием (пос**е**лок, пос**ё**лок). Устраним неявные дубликаты исключим из названия населенного пункта его тип. Для этого создадим список всех типов населенных пунктов с их различным написанием, а после этого пройдёмся автозаменой по элементам таблицы.

# %%
values_to_replace = ['городской ', 'коттеджный ', 'поселок ', 'посёлок ', 
                     'городского типа ', 'при железнодорожной ', 'станции ',
                     'деревня ', 'садоводческое некоммерческое товарищество ',
                     'садовое товарищество ', 'село ']

# %%
print(color.BOLD + 'Колл-во уникальных значений ДО замены:' + color.END, len(data['locality_name'].unique()))
for value in values_to_replace:
    data['locality_name'] = data['locality_name'].str.replace(value, '')
print(color.BOLD + 'Колл-во уникальных значений ПОСЛЕ замены:' + color.END, len(data['locality_name'].unique()))
# Out:
# Колл-во уникальных значений ДО замены: 360
# Колл-во уникальных значений ПОСЛЕ замены: 301

# %% [markdown]
# После автозамены количество уникальных значений уменьшиось.

# %% [markdown]
# **Выводы**
#
# - Данные, в которых отсутствовали названия населенных пунктов были исключены из рассмотрения.
# - В столбце `locality_name` были обнаружены неявные дубликаты, связанные с наличием/отсутствием указания типа населенного пункта (поселок, деревня, и т.д.), а также с их различным написанием (пос**е**лок, пос**ё**лок).
# - Дубликаты были устранены путем исключения типа населенного из названия. После этого количество уникальных значений населенных пунктов уменьшилось с 360 до 301.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно обработал неявные дубликаты. Можно было бы подумать над автоматическим способом обработки, чтобы вручную не указывать все возможные формулировки, приводящие к неявным дубликатам. Оставить только названия, удалив типы, но отталкиваться от того, что в данном случае названия населенных пунктов начинаются с заглавной буквы, можно было обработать строки.

# %% [markdown]
# <div style="border:solid black 2px; padding: 40px">
#     Согласен.
# </div>

# %% [markdown]
# #### Столбец 'airports_nearest'

# %% [markdown]
# `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'airports_nearest')
# Out:
# Характерные значения:
# count    16273.000000
# mean     28909.300559
# std      12909.681035
# min          0.000000
# 25%      18079.000000
# 50%      27144.000000
# 75%      37593.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64
#
# Колл-во пропусков: 5357
#
# Колл-во уникальных значений: 7675
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -11192.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 66864.0
#
# Процентиль 5-ый: 11445.0
#
# Процентиль 95-ый: 51443.0

# %% [markdown]
# Переведем данные из метров в километры, предварительно округлив значения до 100 м (точнее поделив нацело на 100 и тем самым отбросив метры и десятки метров из исходного значения).

# %%
data['airports_nearest'] = data['airports_nearest'] // 100 / 10

# %%
data['airports_nearest'].hist(
    bins=50,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'airports_nearest'",
    xlabel='Расстояние до ближайшего аэропорта, км.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Данные содержат пропуски. Попробуем воспользоваться очевидным приёмом - заполнить пропуски в расстояниях до ближайшего аэропорта, опираясь на медианные значения по каджому населенному пункту.

# %%
median_na_filling('airports_nearest', 'locality_name')
# Out:
# Колл-во пропусков ДО заполнения: 5357
# Колл-во пропусков ПОСЛЕ заполнения: 5289

# %% [markdown]
# **Выводы**
#
# - Значения столбца `airports_nearest` были переведены из метров в километры, с предварительным округлением значений до 100 м.
# - В столбце `airports_nearest` было обнаружено более 5 тыс. пропусков.
# - Часть пропусков (около 100 шт.) удалось обоснованно заполнить, опираясь на медианные значения по каджому населенному пункту.
# - Заполнение оставшихся пропущенных значений на основе имеющихся данных не представляется возможным.
# - Других проблем со значениями в столбце `airports_nearest` не выявлено.
#
# Медианное значение расстояния до аэропорта сосавляет 27.1 км. Отсутствующие значения в столбце могут иметь различную природу. Пропуски могут быть связаны с ошибкой при выгрузке данных, т.к. данное поле рассчитываетя автоматически, а не заполняется человеком. Также можно предположить, что есть некоторое максимальное значение расстояние до аэропорта, после которой указывать ее нет смылста (т.е. случай остутствия аэропорта).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно, нельзя заполнить расстояние до аэропорта общей медианой по всему датафрейму, так как мы работаем с целой областью.

# %% [markdown]
# #### Столбец 'city_centers_nearest'

# %% [markdown]
# `city_centers_nearest` — расстояние до центра города (м)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'city_centers_nearest')
# Out:
# Характерные значения:
# count    16291.000000
# mean     14766.067583
# std       8493.990995
# min        287.000000
# 25%      10354.000000
# 50%      13437.000000
# 75%      16538.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64
#
# Колл-во пропусков: 5339
#
# Колл-во уникальных значений: 7087
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): 1078.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 25814.0
#
# Процентиль 5-ый: 4155.0
#
# Процентиль 95-ый: 32050.0

# %% [markdown]
# Переведем данные из метров в километры, предварительно округлив значения до 100 м (точнее поделив нацело на 100 и тем самым отбросив метры и десятки метров из исходного значения).

# %%
data['city_centers_nearest'] = data['city_centers_nearest'] // 100 / 10

# %%
data['city_centers_nearest'].hist(
    bins=50,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'city_centers_nearest'",
    xlabel='Расстояние до центра города, км.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Данные содержат пропуски. Заполним пропуски в расстояниях до центра города, опираясь на медианные значения по каджому населенному пункту.

# %%
median_na_filling('city_centers_nearest', 'locality_name')
# Out:
# Колл-во пропусков ДО заполнения: 5339
# Колл-во пропусков ПОСЛЕ заполнения: 5289

# %% [markdown]
# Мы видим, что количество пропусков в столбцах `city_centers_nearest` и `airports_nearest` очень близко. Возможно, это одни и те же значения. Проверим это предположение.

# %%
nan_data = data[(data['airports_nearest'].isna() == True)] \
                [['city_centers_nearest',
                  'airports_nearest',
                  'parks_nearest',
                  'ponds_nearest',
                  'parks_around_3000',
                  'ponds_around_3000',
                  'locality_name']]
nan_data
# Out:
#        city_centers_nearest  airports_nearest  parks_nearest  ponds_nearest  \
# 13                      NaN               NaN            NaN            NaN
# 15                      NaN               NaN            NaN            NaN
# 16                      NaN               NaN            NaN            NaN
# 19                      NaN               NaN            NaN            NaN
# 20                      NaN               NaN            NaN            NaN
# ...                     ...               ...            ...            ...
# 21621                   NaN               NaN            NaN            NaN
# 21623                   NaN               NaN            NaN            NaN
# 21624                   NaN               NaN            NaN            NaN
# 21625                   NaN               NaN            NaN            NaN
# 21629                   NaN               NaN            NaN            NaN
#
# ...

# %% [markdown]
# Похоже, что все имеющиеся пропуски в столбце `city_centers_nearest` полностью повторяются и в столбцах `airports_nearest`, `parks_nearest`, `ponds_nearest`, `parks_around_3000`, `ponds_around_3000`.

# %%
nan_data.isna().sum()
# Out:
# city_centers_nearest    5289
# airports_nearest        5289
# parks_nearest           5289
# ponds_nearest           5289
# parks_around_3000       5289
# ponds_around_3000       5289
# locality_name              0
# dtype: int64

# %% [markdown]
# Очень похоже, что все пропуски связаны с продажей недвижимости в пригородах Санкт-Петербурга. Проверим, есть ли среди приведенных объявлений квартиры из Санкт-Петербурга.

# %%
nan_data[nan_data['locality_name'] == 'Санкт-Петербург'].count()
# Out:
# city_centers_nearest    0
# airports_nearest        0
# parks_nearest           0
# ponds_nearest           0
# parks_around_3000       0
# ponds_around_3000       0
# locality_name           0
# dtype: int64

# %% [markdown]
# **Выводы**
#
# - Значения столбца `city_centers_nearest` были переведены из метров в километры, с предварительным округлением значений до 100 м.
# - В столбце `city_centers_nearest` было обнаружено более 5 тыс. пропусков.
# - Часть пропусков (около 50 шт.) удалось обоснованно заполнить, опираясь на медианные значения по каджому населенному пункту.
# - Заполнение оставшихся пропущенных значений на основе имеющихся данных не представляется возможным.
# - Других проблем со значениями в столбце `city_centers_nearest` не выявлено.
#
# После совместного анализа столбцов `city_centers_nearest` и `airports_nearest` и др. мы пришли к выводу, что пропуски в данных столбцах связаны с объектами недвижимости, выставленными на продажу в пригородах Санкт-Петербурга (т.е. в поселках, деревнях, садовых товариществах, и т.д.).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Супер, верное предположение выдвинул и проверил его. Видно, что картографические данные не заполнены в определенных населенных пунктах из пригорода СПб, возможно произошел технический сбой или в принципе система не может вычислить информацию для данных населенных пунктов.

# %% [markdown]
# #### Столбец 'parks_around_3000'

# %% [markdown]
# `parks_around_3000` — число парков в радиусе 3 км

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'parks_around_3000')
# Out:
# Характерные значения:
# count    16292.000000
# mean         0.568377
# std          0.768160
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: parks_around_3000, dtype: float64
#
# Колл-во пропусков: 5338
#
# Колл-во уникальных значений: 4
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -1.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 2.5
#
# Процентиль 5-ый: 0.0
#
# Процентиль 95-ый: 2.0

# %%
data['parks_around_3000'].hist(
    bins=8,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'parks_around_3000'",
    xlabel='Количество парков в окрестности 3 км, шт.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Данные содержат пропуски. Заполним пропуски в столбце `parks_around_3000`, опираясь на медианные значения по каджому населенному пункту.

# %%
median_na_filling('parks_around_3000', 'locality_name')
# Out:
# Колл-во пропусков ДО заполнения: 5338
# Колл-во пропусков ПОСЛЕ заполнения: 5289

# %% [markdown]
# **Выводы**
#
# - В столбце `parks_around_3000` были обнаружены пропуски.
# - Часть пропусков (около 50 шт.) удалось обоснованно заполнить, опираясь на медианные значения по населенному пункту.
# - Оставшаяся часть пропусков, как мы выяснили ранее, связано с объявлениями их пригородов Санкт-Петербурга.

# %% [markdown]
# #### Столбец 'parks_nearest'

# %% [markdown]
# `parks_nearest` — расстояние до ближайшего парка (м)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'parks_nearest')
# Out:
# Характерные значения:
# count    6920.000000
# mean      494.644798
# std       341.329793
# min         1.000000
# 25%       292.000000
# 50%       457.000000
# 75%       617.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64
#
# Колл-во пропусков: 14710
#
# Колл-во уникальных значений: 972
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -195.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 1104.5
#
# Процентиль 5-ый: 94.95
#
# Процентиль 95-ый: 979.0

# %% [markdown]
# Округлим данные с шагом в 50 м. и построим гистограмму.

# %%
data['parks_nearest'] = data['parks_nearest'] // 50 * 50

# %%
data['parks_nearest'].hist(
    bins=50,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'parks_nearest'",
    xlabel='Расстояние до ближайшего парка, м',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Одно из значений сильно выбивается из общего характера распределения. Посмотрим, что это за значение.

# %% [markdown]
# Посчитаем, какое количество среди объявлений из Санкт-Петербурга.

# %%
data[data['locality_name'] == 'Санкт-Петербург'][['locality_name']].count()
# Out:
# locality_name    13967
# dtype: int64

# %% [markdown]
# Посчитаем, какое количество из этих объявлений имеют пропустки в столбце `parks_nearest`.

# %%
data[data['locality_name'] == 'Санкт-Петербург'][['parks_nearest']].isna().sum()
# Out:
# parks_nearest    7780
# dtype: int64

# %% [markdown]
# Посчитаем медианное значение расстояния до юлизжайшего парка в Санкт-Петербурге.

# %%
data[data['locality_name'] == 'Санкт-Петербург'][['parks_nearest']].median()
# Out:
# parks_nearest    450.0
# dtype: float64

# %% [markdown]
# **Выводы**
#
# - В данных были выявлены пропуски, которые мы решили оставить без заполнения. Причины опишем ниже.
# - Значения столбца `parks_nearest` округлили с шагом 50 м.
#
# Как мы выяснили такие параметры как, наличие парков, прудов, расстояние до центра города не актуальны для объявлений из сел, деревень, садовых товариществ, и т.д. Значения в столбце характеризуют распределение непосредственно для Санкт-Петербурга. Заполнить пропущенные значения, опираясь на данные по населенным пунктам будет некорректно, т.к. для Санкт-Петербурга это будет одно значение, которое сильно исказит форму распределения и помешает анализу данных.
#
# Поэтому, мы решили не заполнять пропущенные значения медианным значением. Возможно люди намеренно не стали указывать расстояние до ближайшего парка, если это расстояние превышало 1-1.5 км. Значение `parks_nearest` = 450 м. на исходном распределение выглядит аномальным еще до возможного заполнения пропусков.
#
# Тем не менее исходя из имеющихся данным мы можем сделать вывод о том, что скорее всего люди будут указывать расстояние до близжайшего парка, если такой имеется, и расстояние до него не превышает 1-1.5 км. На гистограмме мы видим, что большая часть парков располагается на расстоянии от 250 до 600 м, а медианное растояние до парка в Санкт-Петербурге составляет 450 м.

# %% [markdown]
# #### Столбец 'ponds_around_3000'

# %% [markdown]
# `ponds_around_3000` — число водоёмов в радиусе 3 км

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'ponds_around_3000')
# Out:
# Характерные значения:
# count    16292.000000
# mean         0.717898
# std          0.899036
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: ponds_around_3000, dtype: float64
#
# Колл-во пропусков: 5338
#
# Колл-во уникальных значений: 4
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -1.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 2.5
#
# Процентиль 5-ый: 0.0
#
# Процентиль 95-ый: 3.0

# %%
data['ponds_around_3000'].hist(
    bins=8,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'ponds_around_3000'",
    xlabel='Количество прудов в окрестности 3 км, шт.',
    ylabel='Количество значений, шт.'
);

# %%
median_na_filling('ponds_around_3000', 'locality_name')
# Out:
# Колл-во пропусков ДО заполнения: 5338
# Колл-во пропусков ПОСЛЕ заполнения: 5289

# %% [markdown]
# **Выводы**
#
# - В столбце `ponds_around_3000` были обнаружены пропуски.
# - Часть пропусков (около 50 шт.) удалось обоснованно заполнить, опираясь на медианные значения по населенному пункту.
# - Оставшаяся часть пропусков, как мы выяснили ранее, связано с объявлениями их пригородов Санкт-Петербурга.

# %% [markdown]
# #### Столбец 'ponds_nearest'

# %% [markdown]
# `ponds_nearest` — расстояние до ближайшего водоёма (м)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'ponds_nearest')
# Out:
# Характерные значения:
# count    7862.000000
# mean      529.752735
# std       275.684562
# min        13.000000
# 25%       314.000000
# 50%       516.000000
# 75%       737.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64
#
# Колл-во пропусков: 13768
#
# Колл-во уникальных значений: 1076
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -320.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 1371.5
#
# Процентиль 5-ый: 102.0
#
# Процентиль 95-ый: 981.95

# %% [markdown]
# Округлим данные с шагом в 10 м. и построим гистограмму.

# %%
data['ponds_nearest'] = data['ponds_nearest'] // 10 * 10

# %%
data['ponds_nearest'].hist(
    bins=50,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'ponds_nearest'",
    xlabel='Расстояние до ближайшего парка, м',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# **Выводы**
#
# - Пропуски в данных в столбце `ponds_nearest` имеет ту же природу, что и в столбце `parks_nearest`, поэтому мы не будем искажать полученное распределение их заполнением.
#
# На гистограмме мы видим, что большая часть прудов располагается на расстоянии от 300 до 730 м, а медианное растояние до пруда в Санкт-Петербурге составляет около 500 м.

# %% [markdown]
# #### Столбец 'days_exposition'

# %% [markdown]
# `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)

# %% [markdown]
# Посмторим на характерные значение столбца.

# %%
describe_column(data, 'days_exposition')
# Out:
# Характерные значения:
# count    18909.000000
# mean       174.869480
# std        213.620352
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        221.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
#
# Колл-во пропусков: 2721
#
# Колл-во уникальных значений: 1103
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -221.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 486.5
#
# Процентиль 5-ый: 9.0
#
# Процентиль 95-ый: 623.6

# %%
data['days_exposition'].hist(bins=100, figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'days_exposition'",
    xlabel='Сколько дней было размещено объявление (от публикации до снятия)',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Построим распределение количества объявлений с пропусками в столбце `days_exposition` в зависимоти от даты размещения объявления.

# %%
days_exposition_na = data.query('days_exposition.isna()')[['days_exposition', 'first_day_exposition']]

days_exposition_na['first_day_exposition'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Распределение количества объявлений с пропусками в 'days_exposition'",
    xlabel='Дата размещения объявления',
    ylabel='Кол-во объявлений, шт.'
);

# %% [markdown]
# **Выводы**
#
# - В столбце 'days_exposition' были обранужены пропуски, которые было решено оставить без изменений.
#
# Скорее всего пропуски связаны с теми объявлениями, которые были размещены, но не сняты с публикации т.к. объекты недвижимости не были проданы. Это косвенное продтверждается тем, что количество объявлений на графике начинает быстро расти при приближении к крайней правой дате на временной шкале. Это вполне естественно, т.к. продажа квартиры требует некоторого времени.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Остальные параметры обработал и рассмотрел также правильно.

# %% [markdown]
# ### Добавление в таблицу новых столбцов

# %% [markdown]
# Добавим в таблицу столбец `square_meter_coast` с ценой за 1 кв.м.

# %%
data['square_meter_cost'] = ((data['last_price'] * 1000) / data['total_area']).astype('int')
data['square_meter_cost'].sort_values().head()
# Out:
# 8948      7
# 12829     9
# 13317    10
# 13027    10
# 9528     10
# Name: square_meter_cost, dtype: int64

# %% [markdown]
# Построим гистограмму распеделения значений стоимости 1 кв.м. жилья.

# %%
data['square_meter_cost'].hist(
    bins=100,
    figsize=(11, 4)).set(
    title="Гистограмма распределения значений столбца 'square_meter_coast'",
    xlabel='Стоимость 1 кв.м. недвижимости, тыс. руб.',
    ylabel='Количество значений, шт.'
);

# %% [markdown]
# Теперь добавим в таблицу столбецы `exposition_weekday`, `exposition_month`, и `exposition_year` с днем недели (0 - понедельник, 1 - вторник, и т.д.), месяцем, и годом публикации объявления.

# %%
data['exposition_weekday'] = data['first_day_exposition'].dt.weekday
data['exposition_month'] = data['first_day_exposition'].dt.month
data['exposition_year'] = data['first_day_exposition'].dt.year
data[['first_day_exposition', 'exposition_weekday', 'exposition_month', 'exposition_year']].head()
# Out:
#   first_day_exposition  exposition_weekday  exposition_month  exposition_year
# 0           2018-07-30                   0                 7             2018
# 1           2018-06-30                   5                 6             2018
# 2           2017-06-28                   2                 6             2017
# 3           2018-02-16                   4                 2             2018
# 4           2016-03-22                   1                 3             2016

# %% [markdown]
# В заключении, добавим столбец `floor_category`, который будет описывать тип этажа: 'первый', 'последний', или 'другой'.

# %%
# Создадим функцию floor_category, которая будет разделять этажи по категориям
def floor_category(df):
    if df['floor'] == 1:
        return 'первый'
    elif df['floor'] == df['floors_total']:
        return 'последний'
    else:
        return 'другой'

# %%
# Применяем метод apply и функцию floors_category к столбцу 'floor_category'
data['floor_category'] = data.apply(floor_category, axis=1)
data[['floor', 'floors_total', 'floor_category']].head()
# Out:
#    floor  floors_total floor_category
# 0      1             3         первый
# 1      6             7         другой
# 2      2             3         другой
# 3      3             5         другой
# 4      2             5         другой

# %% [markdown]
# Посмторим, как выглядит доля квартир по категориям этажа.

# %%
data.pivot_table(
    index='floor_category',
    values='last_price',
    aggfunc='count').plot.pie(
    subplots=True,
    figsize=(8, 8),
    autopct="%.1f",
    fontsize=12,
    title="Доля квартир по категории этажа (первый, последний, другой)"
);

# %% [markdown]
# **Выводы**
#
# Для последующего анализа в таблицу были добавлены следующие столбцы:
#
# - `square_meter_coast` - стоимоть 1 кв.в., тыс. руб.
# - `exposition_weekday` - день недели публикации объявления
# - `exposition_month` - месяц публикации объявления
# - `exposition_year` - год публикации объявления
# - `floor_category` - категория этажа ('первый', 'последний', 'другой')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно добавил новые столбцы, использовал только подходящие методы.

# %% [markdown]
# ### ОБЩИЕ ВЫВОДЫ ПО РАЗДЕЛУ 2

# %% [markdown]
# Рынок жилья в Санкт-Петербурге и соседних населённых пунктах представлен объектами общей площадью от 12 до 900 кв.м. Основную его часть представляют 1, 2, и 3-комнатные квартиры с общей площадью от 40 до 68 кв.м. Количество однакомнатных квартир на рынке практически совпадает с количеством двухкомнатных и составляет около 16 из 23 тыс. объявлений (более 70% от всех объявлений на рынке). А квартиры с количеством комнат от 1 до 3 занимают уже более 95% всего рынка.
#
# Цены на квартиры в основном находятся в диапазоне от 2.75 до 9.85 млн.руб., но разумеется ими не ограничиваются. На рынке присутствует множетсво квартир премиального сегмента, стоимость которых может доходить до 763 млн.руб. Стоимость квадратного метра недвижимости варьируется от 50-130 тыс.руб. со средним значением около 100 тыс.руб.
#
# Большинство домов, предствленных на рынке - это "пяти-" и "девятиэтажки", которые представляют "старый" жилой фонд. Таких домов на рынке более 9 тыс. Третьи по популярности дома - 16-этажные. Это уже дома, построенные в последние десятилетия. Как следствие, больше всего квартир продается в дианазоне от 1 до 8 этажа.
#
# Около 36% квартир имеют балкон. Любопытно, что квартир с тремя балконами меньше, чем с четырмя, а квартир с четырмя балконам меньше, чем с пятью.
#
# Большая часть парков (и прудов) располагается на расстоянии от 250 до 600 м, а среднее растояние до парка в Санкт-Петербурге составляет 450 м.
#
# После предобрабоки данных мы получили "портрет" средней квартиры в Санкт-Петербурге: это двухкомнатная квартира площадью 50 кв.м. с потолками 2.65 м и выходом на балкон. Жилая площадь в квартире состовляет 30 кв.м, а кухня занимает 9 кв.м. Квартира расположена на 4 этаже 9-этажного дома, рядом с парком и прудом. Расстояние до центра города - 13.5 км, а до аэропорта придется добираться 27 км. Стоимость такой квартиры составляла всего 4.5 млн. руб. на момент ее продажи.

# %% [markdown]
# ## ИССЛЕДОВАТЕЛЬСКИЙ АНАЛИЗ ДАННЫХ

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Старайся придерживаться структуры, которая указана в задании, выше тебе нужно было просто обработать данные, а проводить анализ необходимо было уже здесь.

# %% [markdown]
# <div style="border:solid black 2px; padding: 40px">
#     Я долго над этми думал, но пришел к выводу, что такое решение наиболее оптимальное. По заданию ннеобходимо было сначала заполнить пропуски, после этого удалить вылеты, а потом уже - подробно рассмотреть каждвый параметр. Отсечение вылетающих значений (если оно обасновано) может избавить нас от лишней работы по заполнению пропусков (в данном случае так оно и происходит, я проверял:)). Более того, работа с вылетами требует тчательного анализа и обоснования их обработки. Получаеться, что объем работы бы вырос кратно :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты прав, я не спорю, все верно говоришь, просто рекомендация для последующих проектов, чтобы не запутаться в структуре.

# %% [markdown]
# В данном разделе нам предстоить ответить на ряд поставленных перед нами вопросов и решить некоторые задачи:
# 1. Как быстро продавались квартиры.
# 2. Зависит ли цена от:
#     - общей площади
#     - жилой площади
#     - площади кухни
#     - количества комнат
#     - этажа, на котором расположена квартира (первый, последний, другой)
#     - даты размещения (день недели, месяц, год)
# 3. Посчитать среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений и выделили населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# 4. Вычислить стоимость 1 кв.м. недвижимости в зависимости от расстояния до центра Санкт-Петербурга.

# %% [markdown]
# ### Как быстро продавались квартиры?

# %% [markdown]
# Посмотрим на характерные значения столбца.

# %%
describe_column(data, 'days_exposition')
# Out:
# Характерные значения:
# count    18909.000000
# mean       174.869480
# std        213.620352
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        221.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
#
# Колл-во пропусков: 2721
#
# Колл-во уникальных значений: 1103
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): -221.5
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 486.5
#
# Процентиль 5-ый: 9.0
#
# Процентиль 95-ый: 623.6

# %% [markdown]
# Построим гистограмму по всем значениям столбца.

# %%
data['days_exposition'].hist(
    bins=200,
    figsize=(11, 4)).set(
    title='Время продажи квартиры', 
    xlabel='Количествово дней продажи',
    ylabel='Количество объектов'
);
plt.show()

# %% [markdown]
# На гистограмме вы видим вылетающие из общего характера распределения значения в дианазоне до 200 дней. Ограничим значения по оси Х до верхей границы выбросов.

# %%
data['days_exposition'].hist(
    bins=500,
    figsize=(11, 4),
    range=(0, 500)).set(
    title='Время продажи квартиры', 
    xlabel='Количествово дней продажи',
    ylabel='Количество объектов'
);
plt.show()

# %% [markdown]
# Сузив дианазон и увеличив количество бинов характер распределения несколько изменился. Теперь мы хорошо видим вылетающие значения в диапазоне до 100 дней. Построим гистограмму в этом диапазоне.

# %%
data['days_exposition'].hist(
    bins=100,
    figsize=(11, 4),
    range=(0, 100)).set(
    title='Время продажи квартиры', 
    xlabel='Количествово дней продажи',
    ylabel='Количество объектов'
);
plt.show()

# %% [markdown]
# Посмотрим, какие значения выражаются на гистограмме в виде пиков.

# %%
data['days_exposition'].value_counts().head(10)
# Out:
# 45.0    860
# 60.0    524
# 7.0     225
# 30.0    195
# 4.0     168
# 3.0     147
# 90.0    143
# 5.0     139
# 14.0    138
# 9.0     134
# Name: days_exposition, dtype: int64

# %% [markdown]
# **Выводы**

# %% [markdown]
# На гистограмме мы видим, что некоторые значения (7, 30, 45, 60, 90 дней) выбиваются из общего характера распределения. Чаще всего такие выбросы - не случайны. Познакомившись подробнее с правилами размещения объявлений на сервисе мы пришли к следующим выводам:
#
# - Большое количество высоких значений было обнаружено в интервале до 7 дней (3, 4, 5, 7 дней), с выраженным пиком на 7 днях. Мы выяснили, что объявление должно пройти ручную модерацию, длительность которой может занимать от 1 до 14 дней. Вероятнее всего, выбивающиеся из общего характера распределения значения связаны с тем, что часть объявлений не прошли модерацию и были сняты с публикации.
# - Срок размещения платного объявления составляет 30 дней. "...На 31-й день платного размещения включится автопродление. Деньги будут списываться каждые 30 дней из кошелька в кабинете или с привязанной банковской карты. Отключить автопродление нельзя, просто снимите объявление с публикации, если оно больше неактуально...". Таким образом пик на 30 днях объявняется снятией с публицации платных объявлений.
# - Также мы выяснили, что срок бесплатного размещения объявлений у квартир - ограничен. Бесплтаный срок размещения квартир до 4.5 млн составляет 45 дней, от 4.5 до 10 млн - 60 дней, а от 10 млн - 90 дней. Именно эти значения  выражаются на графике сильнее других.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-04-13%20%D0%B2%2008.51.09.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-04-13%20%D0%B2%2008.51.09.png)

# %% [markdown]
# - Половина квартир продаются в период до 93 дней. При этом среднее значение времени продажи квартиры - примерно 180 дней.
# - Необычно долгими продажами будем считать те 25% квартир, которые продавались _дольше_ остальных: 294 и более дней.
# - Напротив, быстрыми продажами будем считать те 25% квартир, которые продавались _быстрее_ остальных: 44 и менее дней.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Полностью согласен с твоим выводом, молодец!

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость объекта?

# %% [markdown]
# Рассмотрим детальнее следующие параметры:
# 1. общая площадь
# 2. жилая площадь
# 3. площадь кухни
# 4. количество комнат
# 5. тип этажа, на котором расположена квартира (первый, последний, другой)
# 6. дата размещения
#  - день недели
#  - месяц
#  - год

# %% [markdown]
# #### Общая площадь

# %% [markdown]
# Посчитаем корреляцию между ценой и общей площадью объекта нелвижимости.

# %%
data['last_price'].corr(data['total_area'])
# Out:
# 0.7284448115662197

# %%
data.pivot_table(
    index='total_area',
    values='last_price',
    aggfunc='median').plot(
    style='x',
    title='График зависимоти общей площади от стоимости квартиры',
    xlabel='Общая площадь, кв. м.',
    ylabel='Стоитость объектра нелвижимости, млн. руб.'
);

# %% [markdown]
# **Выводы**
#
# Цена квартиры, ожидаемо, увеличивается с увеличением общей площади квартиры. Корреляция этих двух параметров равна 0.75. Сам факт подтверждения результатми реальной природы вещей говорит о том, что и с данными все в порядке, и мы не совершили ошибок при их обработке.
#
# Здесь можно заметить еще один любопытный момент. Значения в диапазоне от 20 до 100 кв.м. достаточно хорошо аппрокимируются линейной функцией. Облако точек начинает понемного "разваливаьтся" начиная с 50 кв.м.. Это может говорить о том, что квартиры с близкой общей площадью в диапазоне от 20 до 50 кв.м. достаточно близки по своим характеристикам в целом, в то время как квартиры за пределами этого диапазона при близкой площади могут различаться по другим свойствам, оказывающим влияние на ценообразование.

# %% [markdown]
# #### Жилая площадь

# %% [markdown]
# Посчитаем корреляцию между ценой и жилой площадью объекта нелвижимости.

# %%
data['last_price'].corr(data['living_area'])
# Out:
# 0.6218316955099782

# %%
data.pivot_table(
    index='living_area',
    values='last_price',
    aggfunc='median').plot(
    style='x',
    title='График зависимоти жилой площади от стоимости квартиры',
    xlabel='Общая площадь, кв. м.',
    ylabel='Стоитость объектра нелвижимости, млн. руб.'
);

# %% [markdown]
# **Выводы**
#
# Ситация с жилой площадью аналогична той, что мы наблюдали выше с общей площадью. Здесь, правда уже больше выражен экспоненциальные характер распределения точек, что больше подходит для описания зависимости подобных параметров.

# %% [markdown]
# #### Площадь кухни

# %% [markdown]
# Посмотрим на характерные значения столбца.

# %%
describe_column(data, 'kitchen_area')
# Out:
# Характерные значения:
# count    21630.000000
# mean         9.396893
# std          3.189345
# min          3.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.000000
# max         20.000000
# Name: kitchen_area, dtype: float64
#
# Колл-во пропусков: 0
#
# Колл-во уникальных значений: 1245
#
# Нижняя граница выбросов (Q1 - 1.5*lQR): 1.0
#
# Верхняя граница выбросов (Q3 + 1.5*lQR): 17.0
#
# Процентиль 5-ый: 5.3
#
# Процентиль 95-ый: 15.55

# %% [markdown]
# Посчитаем корреляцию между ценой и площадью кухни объекта нелвижимости.

# %%
data['last_price'].corr(data['kitchen_area'])
# Out:
# 0.5498703710352978

# %%
data.pivot_table(
    index='kitchen_area',
    values='last_price',
    aggfunc='median').plot(
    style='x',
    title='График зависимоти площади кухни от стоимости квартиры',
    xlabel='Общая площадь, кв. м.',
    ylabel='Стоитость объектра нелвижимости, млн. руб.'
);

# %% [markdown]
# **Выводы**
#
# Казалось бы, все три параметра: общая площадь, жилая площадь, и площадь кухни очень близки по своему смыслу и от них стоит ожидать достаточно близких графиков зависимости от цены. Но на деле мы наблюдаем несколько иную картину. В целом, все три параметра показывают один ожидаемый результат - **цена на недвижимость увеличивается при росте общей площади, жилой площади, и площади кухни**. Но каждый из параметров демонстрирует разную корреляцию. Площадь кухни - наименее устойчивый параметр (из трех расмотренных) для определения зависимости стоимости квартиры от ее площади. Можно утверждать, в области менее типичных значений для площади кухни (примерно выше 12 кв.в.) корреляция между ценой на недвижимость и площадью кухни сильно ухудшается (практически отсутствует).

# %% [markdown]
# #### Количество комнат

# %% [markdown]
# Посчитаем корреляцию между ценой и площадью кухни объекта недвижимости.

# %%
data['last_price'].corr(data['rooms'])
# Out:
# 0.43954791616648736

# %%
data.pivot_table(index='rooms', values='last_price', aggfunc='median')
# Out:
#        last_price
# rooms
# 0            2.75
# 1            3.59
# 2            4.68
# 3            5.90
# 4            7.38
# 5            8.50
# 6            9.85

# %%
data.pivot_table(
    index='rooms',
    values='last_price',
    aggfunc='median').plot(
    style='-o',
    title='График зависимоти количества комнат от стоимости квартиры',
    xlabel='Количество комнат',
    ylabel='Стоитость объектра нелвижимости, млн. руб.',
    grid=True
);

# %% [markdown]
# **Выводы**
#
# Здесь также без сюрпризов - с увеличением количества комнат цена на недвижимость увеличивается.
# Медианная стоимость квартир меняется от 3.59 млн. за однокомнатную квартиру до 9.85 млн. за шестикомнатную. Студия в среднем обойется в 2.75 млн.

# %% [markdown]
# #### Этаж, на котором расположена квартира

# %%
floor_type = data.pivot_table(
    index='floor_category',
    values='last_price',
    aggfunc=['count', 'median'])
floor_type.columns = ['number', 'median_price']

# %%
floor_type['median_price'].plot(
    style='o',
    title='Зависимоть между категорией этажа и стоимостью квартиры',
    xlabel='Категория этажа',
    ylabel='Стоитость объектра нелвижимости, млн. руб.',
    grid=True
);

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Забыл здесь и ниже изменить подписи осей.

# %% [markdown]
# <div style="border:solid black 2px; padding: 40px">
#     Упс. исправил :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Супер!

# %% [markdown]
# **Выводы**
#
# - График показывает, что цена на квартиру на первом и последнем этажа в среднем меньше, чем на любом другом.
# - При этом первый этаж демонстрирует самую низкую среднюю цену в 3.8 млн.руб.

# %% [markdown]
# #### Дата размещения

# %% [markdown]
# Проверим, как менялась средняя цена в зависимости от дня недели, месяца, и года публикации объявления. По каждому параметры построим сводную таблицу, в которой отобразим медианнаое среднее, среднее арифметическое значение, и количество элементов внутри группы. Количество элементов необходимо, чтобы избежать ложных выводов, связанных с недостаточно большой выборкой значений внутри отдельной группы.

# %% [markdown]
# ##### День недели размещения объявления

# %%
data.pivot_table(index='exposition_weekday', values='last_price', aggfunc=['median', 'mean', 'count'])
# Out:
#                        median       mean      count
#                    last_price last_price last_price
# exposition_weekday
# 0                        4.50   5.184765       3297
# 1                        4.50   5.208561       3837
# 2                        4.50   5.218105       3615
# 3                        4.45   5.159974       3876
# 4                        4.40   5.110819       3664
# 5                        4.40   5.023485       1785
# 6                        4.42   5.069210       1556

# %%
data.pivot_table(
    index='exposition_weekday',
    values='last_price',
    aggfunc='median').plot(
    style='-o',
    title='Зависимоть между днем недели размещения \n объявления и стоимостью квартиры',
    xlabel='День недели',
    ylabel='Стоитость объектра нелвижимости, млн. руб.',
    grid=True
);

# %% [markdown]
# **Вывод**
#
# - Объявления, опубликованные в конце рабочей недели (с пятницы по воскресения) в среднем на 100 тыс. дешевлле, чем объявления, опубликованные в начале недели (с понедельница по четверг).

# %% [markdown]
# ##### Месяц размещения объявления

# %%
data.pivot_table(index='exposition_month', values='last_price', aggfunc=['median', 'mean', 'count'])
# Out:
#                      median       mean      count
#                  last_price last_price last_price
# exposition_month
# 1                      4.49   5.189188       1355
# 2                      4.45   5.120897       2419
# 3                      4.50   5.124844       2372
# 4                      4.60   5.282563       2185
# 5                      4.35   5.029599       1147
# 6                      4.25   5.003576       1619
# 7                      4.40   5.082993       1527
# 8                      4.45   5.170977       1597
# 9                      4.50   5.325296       1807
# 10                     4.45   5.155538       1961
# 11                     4.50   5.190830       2157
# 12                     4.50   5.112729       1484

# %%
data.pivot_table(
    index='exposition_month',
    values='last_price',
    aggfunc='median').plot(
    style='-o',
    title='Зависимоть между месяцем размещения \n объявления и стоимостью квартиры',
    xlabel='Месяц',
    ylabel='Стоитость объектра нелвижимости, млн. руб.',
    grid=True
);

# %% [markdown]
# **Вывод**
#
# - Объявления с самыми дешевыми ценами на недвижимость размещаются в июне, а самые дорогоие - в апреле.
# - Получается в среднем, цена на недвижимость с апреля по июнь снижается примерно на 7%.

# %% [markdown]
# ##### Год размещения объявления

# %%
data.pivot_table(index='exposition_year', values='last_price', aggfunc=['median', 'mean', 'count'])
# Out:
#                     median       mean      count
#                 last_price last_price last_price
# exposition_year
# 2014                  5.94   6.910722         97
# 2015                  4.95   5.691360       1007
# 2016                  4.30   5.114319       2503
# 2017                  4.30   5.066791       7485
# 2018                  4.45   5.072451       7908
# 2019                  4.89   5.430810       2630

# %%
data.pivot_table(
    index='exposition_year',
    values='last_price',
    aggfunc='median').plot(
    style='-o',
    title='Зависимоть между годом размещения \n объявления и стоимостью квартиры',
    xlabel='Год',
    ylabel='Стоитость объектра нелвижимости, млн. руб.',
    grid=True
);

# %% [markdown]
# **Выводы**
#
# - Средняя цена на недвижимость в период с 2014 по 2016 год с 5.94 до 4.3 млн., в следующем 2017 году цена не изменилась, а в последующих 2018 и 2019 годах продемонстрировала рост до 4.89 млн.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно проанализировал, видно, что цена больше всего зависит от параметров площади и количества комнат. Прослеживается некоторая сезонность в продажах. Подходящие типы диаграмм подобрал для каждой пары случайных величин, у тебя отлично получается проводить анализ и выявлять все нюансы.

# %% [markdown]
# ### Населённые пункты с самой высокой и низкой стоимостью квадратного метра

# %% [markdown]
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений и выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
data_m2_local_coast = data.pivot_table(
    index='locality_name',
    values='square_meter_cost',
    aggfunc=['count', 'median']
)

data_m2_local_coast.columns = ['number_of_ads', 'm2_median_cost']

data_m2_local_coast = data_m2_local_coast.sort_values(
    by='number_of_ads',
    ascending=False
).head(10).sort_values(
    by='m2_median_cost',
    ascending=False
)

data_m2_local_coast
# Out:
#                  number_of_ads  m2_median_cost
# locality_name
# Санкт-Петербург          13967           103.0
# Пушкин                     332            98.0
# Кудрово                    450            95.0
# Парголово                  317            91.0
# Мурино                     574            86.0
# Шушары                     432            76.0
# Колпино                    331            74.0
# Гатчина                    301            67.0
# Всеволожск                 386            65.0
# Выборг                     222            58.0

# %% [markdown]
# Посмотрим на процентное соотношение объявлений среди  выделенных 10 населённых пунктов с наибольшим числом объявлений.

# %%
data_m2_local_coast['number_of_ads'].plot.pie(
    subplots=True,
    figsize=(8, 8),
    autopct="%.1f",
    fontsize=12,
    title='Доля каждого из 10 населённых пунктов с наибольшим числом объявлений'
);

# %% [markdown]
# **Выводы**
#
# - Самая высокая стоиомть 1 кв.м.*, как и ожидалось, в Санкт-Петербурге. Здесь она составила 103 тыс. руб.
# - Самая низка стоимость 1 кв.м.* - в Выборге. Там она составила 58 тыс. руб.
# - Среди 10 населённых пунктов с наибольшим числом объявлений доля объявлений, приходящихся на Санкт-Петербург составляет 80.7%.
#
# *среди 10 населённых пунктах с наибольшим числом объявлений

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Именно так, самые дорогие квартиры в СПб, а дешевые в Выборге.

# %% [markdown]
# ### Как стоимость объектов зависит от расстояния до центра города в Санкт-Петербурге?

# %% [markdown]
# Рассмотрим зависимость полной цены квартиры от ее расстояния до центра.

# %%
# Округлим значения расстояние до центра до целых значений
data['city_centers_nearest_step_1km'] = round(data['city_centers_nearest'], 0)

# %%
# Выделим значения по Санкт-Петербургу в отдельный датафрейм
data_spb = data.loc[data.loc[:, 'locality_name']=='Санкт-Петербург']

# %%
# Построим сводную таблицу, отражающую зависимость полной стоимости квартиры от расстояния до центра
data_spb = data.query("locality_name == 'Санкт-Петербург'").pivot_table(
    index='city_centers_nearest_step_1km',
    values='last_price',
    aggfunc='median'
)

# %%
# Построим график
data_spb.plot(
    figsize=(11, 4),
    grid=True,
    kind='line',
).set(
    xlabel='Расстояние до центра, км.',
    ylabel='Полная стоимость квартиры, млн., руб.',
    title='Зависимость полной цены квартиры от ее расстояния до центра Санкт-Петербурга'
);

# %%
data_spb
# Out:
#                                last_price
# city_centers_nearest_step_1km
# 0.0                                 8.000
# 1.0                                 9.000
# 2.0                                 8.540
# 3.0                                 7.450
# 4.0                                 7.970
# 5.0                                 8.000
# 6.0                                 7.500
# 7.0                                 6.500
# 8.0                                 6.500
# 9.0                                 5.200
# 10.0                                4.900
# 11.0                                4.950
# 12.0                                4.950
# 13.0                                5.150
# 14.0                                4.800
# 15.0                                4.800
# 16.0                                4.670
# 17.0                                4.580
# 18.0                                4.300
# 19.0                                4.500
# 20.0                                4.700
# ...

# %% [markdown]
# Теперь посмотрим на график зависимости стоимости 1 кв.м. недвидимости в зависимости от расстояния до центра. На этот раз мы по оси Х отложим значения расстояния без их округления до целых, чтобы посмотреть устойчивость цены за 1 кв.м. при ее незначительны изменениях. Полученную кривую мы осредним с скользяшем окне чтобы исключить влияние выбросов и оценить реальный тренд.

# %%
price = data.query("locality_name == 'Санкт-Петербург'").pivot_table(
    index='city_centers_nearest',
    values='square_meter_cost',
    aggfunc='median'
)

# %%
# Считаем медианное значение цены 1 кв.м. в скользящем окне (21 знач.)
ma = price['square_meter_cost'].rolling(21).median()

# Считаем стандартное отклонение значения цены 1 кв.м. в скользящем окне (21 знач.)
mstd = price['square_meter_cost'].rolling(21).std()

# Задаем свойста графика
plt.figure(figsize=(11, 4));
plt.grid(True);
plt.xlabel('Расстояние до центра, км.');
plt.ylabel('Стоимость 1 кв.м., тыс, руб.');
plt.title('Стоимость 1 кв.м. недвижимости в зависимости от расстояния до центра Санкт-Петербурга');

# График стоимости 1 кв.м. недвижимости в зависимости от расстояния до центра Санкт-Петербурга'
# (черная кривая на графике)
plt.plot(price.index, price, "k");

# График медианной стоимости 1 кв.м., рассчитанной в скользящем окне
# (синяя кривая на графике)
plt.plot(ma.index, ma, "b"); 

# "Коридор" станартного отклонения значений стоимости 1 кв.м., рассчитанный в скользящем окне
# (зеленая область кривая на графике)
plt.fill_between(mstd.index, ma - 2 * mstd, ma + 2 * mstd, color="g", alpha=0.2);

# %% [markdown]
# Посчитаем среднюю стоимость 1 км при приближении к центу. Значения цены и расстояния снимем с синей кривой, т.к. она менее подвержена выбросам.

# %%
price_delta = ma.max() - ma.min()
distance_delta = ma[ma == ma.min()].index[0] - ma[ma == ma.max()].index[0]
m2_pre_km_price = round(price_delta / distance_delta, 2)
m2_pre_km_price
# Out:
# 1.68

# %% [markdown]
# **Выводы**
#
# - Цена за 1 кв.м. недвижимости в Санкт-Петербурге уменьшается от 130 тыс. руб. в центре (до 5 км), до примерно 80 тыс.руб. на расстоянии 20-30 км от центра.
# - При приближении к центру стоимость 1 кв.м. недвижимости в среднем увеличивается на 1.68 тыс.руб. на 1 км.
#
# В целом, за исключением нескольких выбирающихся из общего тренда значений, мы видим, что цена на недвижимость уменьшается по мере удаления от центра. При этом оследует отметить характер этого изменения. Примерно от 0 до 9 км цена стремительно уменьшается с 9 до 5 млн. руб., после чего скорость уменьшения сильно замедляется и с 10 по 21 км цена практически перестает уменьшатся и остается на уровне 5 млн. руб. Дальше цена снова начинает падать и достигает своего минимального значения 3 млн.руб. в окрестности 27 км.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Здесь нужно рассмотреть зависимость общей цены квартир от расстояния до центра. При этом расстояние до центра нужно перевести в километры и округлить до целых. Тогда можно будет построить сводную таблицу, где индексы это расстояние до центра (1, 2, 3.. км), а в значения средняя цена квартир на таком удалении.

# %% [markdown]
# <div style="border:solid black 2px; padding: 40px">
#     Поправил, дополнил выводы.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно, описал зависимость цены от расстояния до центра абсолютно верно. Молодец!

# %% [markdown]
# ### ОБЩИЕ ВЫВОДЫ ПО РАЗДЕЛУ 3

# %% [markdown]
# Продажа квартир - процесс ответственный, и может занимать от первых недель до нескольких лет. Половина квартир продаются в период до 93 дней. При этом среднее значение времени продажи квартиры - примерно 180 дней.
# Необычно долгими можно считать продажи за 294 и более дней. Быстрые продажи занимают обычно 44 и менее дней.
#
# Рост всех очевидных параметров, таких как общая и жилая площадь, площадь кухни, и количество комнат, ожидаемо приводит к увеличению стоимости недвижимости. Это полностью подтверждается проведенными нами построениями. При этом до некоторых пор (примерно от 20 до 100 кв.м) рост стоимости квартир близок к линейному (примерно от 3 до 100 млн.руб.), т.е.  т.е. подавляющее большинство объявлений укладывается в эти критерии. Квартиры, которые находятся в диапазоне с долее высокой общей площадью, могу иметь весьма существенный разброс цен.
#
# Наблюдения показали, что цена на квартиру на первом и последнем этажа в среднем меньше, чем на других этажах. При этом первый этаж демонстрирует самую низкую среднюю цену в 3.8 млн.руб.
#
# Также можно отметить сезонность продаж. Объявления с самыми дешевыми ценами на недвижимость размещаются в июне, а самые дорогоие - в апреле. Получается в среднем, цена на недвижимость с апреля по июнь снижается примерно на 7%.
# В целом можно отметить тенденцию к росту стоимости жилья в течение последних нескольких лет.
#
# Самая высокая стоиомть 1 кв.м.*, как и ожидалось, в Санкт-Петербурге. Здесь она составила 103 тыс. руб. Самая низкая стоиомть 1 кв.м.* - в Выборге. Там она составила 58 тыс. руб. Доля объявлений*, приходящихся на Санкт-Петербург составляет 80.7%.
#
# Цена за 1 кв.м. недвижимости в Санкт-Петербурге уменьшается от 130 тыс. руб. в центре (до 5 км), до примерно 80 тыс.руб. на  расстоянии 20-30 км до центра. При приближении к центру стоимость 1 кв.м. недвижимости в среднем увеличивается на 1.68 тыс.руб. на 1 км.
#
# ---
#
# _(* - среди 10 населённых пунктов с наибольшим числом объявлений)_

# %% [markdown]
# ## ОБЩИЕ ВЫВОДЫ ПО ПРОЕКТУ

# %% [markdown]
# Представленные для анализа данные содержали информацию о рынке жилой недвижимости Санкт-Петербурга в период с 2014 по 2019 год. По каждой квартире в базе содержится два типа данных: добавленные пользователем и картографические. К первому типу относятся площадь квартиры, её этаж и количество балконов, ко второму — расстояния до центра города, аэропорта и ближайшего парка.
#
# В процессе предварительной обработки данных был проведен детальный анализ каждого столбца таблицы в отдельности. Числовые столбцы изучались на предмет наличия пропусков, ошибочных значений, вылетов. Столбцы с названиями были проверены на наличие неявных дубликатов. Все столбцы также были преобразованы к типу, соответствующему их значениям.
#
# Пропуски в данных по большей части относились к столбцам, которые не оказывали ключевую роль при анализе. Большая часть пропусков связана с необязательными для заполнения полями. Также в данных встречались ошибки, связанные с ошибками заполнения параметров пользователем. При заполнении пропусков мы использовали различные способы. Часть значений мы заполняли путем группировки данных по столбцу и расчету медианных значений внутри каждой группы. В отдельных случаях мы расчитывали масштабный коэффициент, которых пересчитывал значения одного столбца в значения другого. В тех столбцах, где заполнение пропусков не имело осонаний мы оставили, пропущенные значения были оставлены без изменений, или исключены из рассмотрения.
#
# Особое значение было уделено устранению вылетающих значений. При работе с данными, содержащими стоимоть товаров, особенно, если в одной выборке пересекаются рынки товаров "эконом" и "премиум" классов, достоверное определение выбросов может быть затруднительно. Поэтому при отбраковке значений мы старались быть максимально объективными и руководствоваться не только количественными показателями, но и опираться на здравый смысл, пытаясь по возможности не выкинуть "лишнего".
#
# После предобрабоки данных мы получили "портрет" средней квартиры в Санкт-Петербурге: это двухкомнатная квартира площадью 50 кв.м. с потолками 2.65 м и выходом на балкон. Жилая площадь в квартире состовляет 30 кв.м, а кухня занимает 9 кв.м. Квартира расположена на 4 этаже 9-этажного дома, рядом с парком и прудом. Расстояние до центра города - 13.5 км, а до аэропорта придется добираться 27 км. Стоимость такой квартиры составляла всего 4.5 млн. руб. на момент ее продажи.
#
# Для последующего анализа в таблицу были добавлены следующие столбцы:
#
# - `square_meter_coast` - стоимоть 1 кв.в., тыс. руб.
# - `exposition_weekday` - день недели публикации объявления
# - `exposition_month` - месяц публикации объявления
# - `exposition_year` - год публикации объявления
# - `floor_category` - категория этажа ('первый', 'последний', 'другой')
#
# В ходе исследовательского анализа мы выполнили все посталенные перед нами задачи:
# 1. Изучили, как быстро продавались квартиры.
# 2. Изучили, зависит ли цена от:
#     - общей площади
#     - жилой площади
#     - площади кухни
#     - количества комнат
#     - этажа, на котором расположена квартира (первый, последний, другой)
#     - даты размещения (день недели, месяц, год)
# 3. Посчитали среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений и выделили населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# 4. Вычислили стоимость 1 кв.м. недвижимости в зависимости от расстояния до центра Санкт-Петербурга.
#
# Подробные выводы с ответами на поставленные вопросы мы привели в соответствующем разделе.
#
# В заключении отметим, что в ходе проведенного анализа, мы не проводили мы не делали сегментацию объявлений, поскольку перед нами стояла иная задача, а лишь смотрели средние показатели по рынку. Дальнейшее углубленное изучение данных может быть направлено как раз на изучение отдельных классов объектов недвижимости, например, объекты "эконом", "комфорт", и "бизнесс" класса. Подобное разделение позволит получить более точные характеристики изучаемых объектов и приведет к более точным прогнозам.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный вывод, все четко, понятно и структурировано. Вывод в полной мере отражает существующие зависимости, и по нему можно принимать дальнейшие решения.
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Я уверен, что ты приложил все усилия, чтобы сделать этот проект. Это видно по твоей работе, а сформулированные выводы отражают, насколько успешно ты осваиваешь материал.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Ты полностью следовал всем этапам выполнения задания и справился почти со всем. Хорошая работа!
# * Отдельно выделю некоторые выводы, которые ты смог сформулировать абсолютно точно!
# * У тебя опрятный и читаемый код. Возможно это звучит банально, однако при работе с чужим кодом это крайне важно)
#
#
# **На что стоит обратить внимание🤓**:
#
# * Нужно корректно обработать признак апартаментов.
# * В последнем пункте нужно скорректировать расчет.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid black 2px; padding: 40px">
#     Анзор, искренне благодарю тебя за оперативную проверку задания :) Спасибо за замечания и советы, все учел и поправил.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Ты отлично справился с данной работой! Видно, как ты успешно осваиваешь материал, применяешь полученные знания на практике. Мне было очень приятно проверять твою работу, надеюсь, мои комментарии и советы были для тебя полезными.
#
# **Желаю удачи в последующем обучении и исследованиях!**😉
